# %%
import pandas as pd

data_path = 'CM_logD_regression.xlsx'


df = pd.read_excel(data_path, sheet_name='Ni')

# %%
df
# Out:
#       pH   A/O  [D2EHPA]   extraction %      Dobs  log D (obs)  [Mn] (mol/L)  \
# 0   3.86  2.00       0.15          6.18  0.131742    -0.880277          0.14
# 1   3.53  1.00       0.35         30.81  0.445296    -0.351352          0.14
# 2   2.59  2.00       0.15          3.95  0.082249    -1.084870          0.14
# 3   2.53  2.00       0.35         -4.80 -0.091603          NaN          0.14
# 4   3.06  1.00       0.35          5.80  0.061571    -1.210623          0.14
# 5   3.54  1.00       0.15         13.02  0.149690    -0.824808          0.06
# 6   2.50  2.00       0.15          3.60  0.074689    -1.126745          0.14
# 7   2.50  2.00       0.35          8.69  0.190341    -0.720469          0.06
# 8   3.54  1.00       0.35          7.61  0.082368    -1.084240          0.14
# 9   2.50  1.00       0.15          0.17  0.001703    -2.768812          0.14
# 10  3.51  2.00       0.15         16.83  0.404713    -0.392853          0.06
# 11  2.56  1.00       0.35         25.13  0.335648    -0.474115          0.06
# 12  2.67  2.00       0.15         20.90  0.528445    -0.277000          0.14
# 13  2.51  1.00       0.35         10.46  0.116819    -0.932485          0.14
# 14  2.52  1.00       0.15          9.59  0.106072    -0.974398          0.06
# 15  3.50  1.00       0.15         32.00  0.470588    -0.327359          0.06
# 16  2.51  1.00       0.15          4.89  0.051414    -1.288917          0.14
# 17  3.50  2.00       0.15         25.53  0.685645    -0.163901          0.06
# 18  3.51  2.00       0.35          9.01  0.198044    -0.703239          0.14
# 19  3.53  2.00       0.35         37.82  1.216468     0.085101          0.06
# 20  2.60  2.00       0.35         17.54  0.425418    -0.371184          0.06
# 21  3.54  2.00       0.35         31.60  0.923977    -0.034339          0.06
# 22  2.51  1.00       0.35         13.15  0.151410    -0.819844          0.06
# 23  2.50  1.00       0.15          2.51  0.025746    -1.589286          0.06
# 24  4.51  1.50       0.25          6.79  0.109269    -0.961501          0.01
# 25  3.01  1.50       0.25          5.69  0.090499    -1.043354          0.19
# 26  3.04  1.50       0.25          4.86  0.076624    -1.115636          0.10
# 27  3.00  1.50       0.25         -0.47 -0.007017          NaN          0.10
# 28  3.07  1.50       0.25          0.41  0.006175    -2.209341          0.10
# 29  3.08  1.50       0.25         -1.74 -0.025654          NaN          0.10
# 30  3.00  1.50       0.25          7.81  0.127075    -0.895942          0.10
# 31  3.06  1.50       0.25          2.11  0.032332    -1.490365          0.10
# 32  3.07  1.50       0.03         16.10  0.287843    -0.540845          0.10
# 33  3.00  1.50       0.47         12.40  0.212329    -0.672991          0.10
# 34  3.00  0.39       0.25         43.58  0.301244    -0.521081          0.10
# 35  3.02  2.61       0.25          9.46  0.272704    -0.564309          0.10
# 36  1.90  1.50       0.25         -3.21 -0.046652          NaN          0.10
# 37  4.11  1.50       0.25         21.92  0.421107    -0.375608          0.10
# 38  3.01  1.50       0.25         10.59  0.177665    -0.750399          0.10
# 39  3.14  1.50       0.25          9.31  0.153986    -0.812518          0.10
#
#     [Co] (mol/L)  [Ni] (mol/L)  [Cu] (mol/L)
# 0       0.000056      0.000140      0.000140
# 1       0.000056      0.000140      0.000060
# 2       0.000056      0.000140      0.000140
# 3       0.000056      0.000060      0.000060
# 4       0.000024      0.000140      0.000140
# 5       0.000056      0.000060      0.000140
# 6       0.000024      0.000140      0.000060
# 7       0.000056      0.000140      0.000060
# 8       0.000056      0.000060      0.000140
# 9       0.000024      0.000060      0.000140
# 10      0.000024      0.000140      0.000060
# 11      0.000056      0.000140      0.000060
# 12      0.000056      0.000060      0.000140
# 13      0.000024      0.000060      0.000060
# 14      0.000024      0.000140      0.000140
# 15      0.000056      0.000060      0.000060
# 16      0.000024      0.000140      0.000060
# 17      0.000056      0.000060      0.000060
# 18      0.000024      0.000060      0.000060
# 19      0.000024      0.000060      0.000140
# 20      0.000024      0.000060      0.000140
# 21      0.000024      0.000140      0.000140
# 22      0.000056      0.000140      0.000140
# 23      0.000024      0.000060      0.000060
# 24      0.000040      0.000100      0.000100
# 25      0.000040      0.000100      0.000100
# 26      0.000005      0.000100      0.000100
# 27      0.000075      0.000100      0.000100
# 28      0.000040      0.000012      0.000100
# 29      0.000040      0.000189      0.000100
# 30      0.000040      0.000100      0.000012
# 31      0.000040      0.000100      0.000189
# 32      0.000040      0.000100      0.000100
# 33      0.000040      0.000100      0.000100
# 34      0.000040      0.000100      0.000100
# 35      0.000040      0.000100      0.000100
# 36      0.000040      0.000100      0.000100
# 37      0.000040      0.000100      0.000100
# 38      0.000040      0.000100      0.000100
# 39      0.000040      0.000100      0.000100

# %%
df.head()

# Remove rows with NaN values
df = df.dropna()

# Reset index after dropping NaN values
df = df.reset_index(drop=True)
df
# # scale each column by doing df[col] = df[col] / abs(df[col]).max()
for col in df.columns:
    if df[col].dtype in ['float64', 'int64']:
        max_value_ = abs(df[col]).max()
        scaled_column_name = f"{col}_scaled"
        df[scaled_column_name] = df[col] / max_value_
        print(f"Scaled {col} by {max_value_}")


# Remove idx = 31 from data
# Out:
# Scaled pH by 4.51
# Scaled A/O by 2.61
# Scaled [D2EHPA]  by 0.47
# Scaled extraction % by 43.58
# Scaled Dobs by 1.2164683177870699
# Scaled log D (obs) by 2.7688121497348264
# Scaled [Mn] (mol/L) by 0.19
# Scaled [Co] (mol/L) by 5.6e-05
# Scaled [Ni] (mol/L) by 0.00014
# Scaled [Cu] (mol/L) by 0.000189

# %%
df
# Out:
#       pH   A/O  [D2EHPA]   extraction %      Dobs  log D (obs)  [Mn] (mol/L)  \
# 0   3.86  2.00       0.15          6.18  0.131742    -0.880277          0.14
# 1   3.53  1.00       0.35         30.81  0.445296    -0.351352          0.14
# 2   2.59  2.00       0.15          3.95  0.082249    -1.084870          0.14
# 3   3.06  1.00       0.35          5.80  0.061571    -1.210623          0.14
# 4   3.54  1.00       0.15         13.02  0.149690    -0.824808          0.06
pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)


# Parameters
n_a = 6
n_b = 2
m.a_set = pyo.Set(initialize = np.arange(1, n_a+1))
m.b_set = pyo.Set(initialize = np.arange(1, n_b+1))


m.ai = pyo.Var(m.a_set, domain=pyo.Reals, initialize=0.0)
m.bi = pyo.Var(m.b_set, domain=pyo.Reals, initialize=0.0)


name_mapper = {
    'pH_scaled': m.pH,
    '[D2EHPA] _scaled': m.C_ex,
    '[Mn] (mol/L)_scaled': m.CMn_fd,
    '[Co] (mol/L)_scaled': m.CCo_fd,
    '[Ni] (mol/L)_scaled': m.CNi_fd,
    '[Cu] (mol/L)_scaled': m.CCu_fd,
    'log D (obs)_scaled': m.logD
}

# Initialize input variables
for col in name_mapper.keys():
    for i in df.index:
        name_mapper[col][i].fix(df[col][i])

# Model variales

m.logD_scaled_pred =  pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.Cext_net_pred = pyo.Var(m.I, domain=pyo.Reals, initialize=1e-3)
m.logCext_net_pred = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)

m.a = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.b = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)


for i in range(3,7):
    m.ai[i].bounds = (0, None)

# Constraints

@m.Constraint(m.I)
def logCext_net_pred_constraint(m, i):
    return 10**(m.logCext_net_pred[i]) == (m.Cext_net_pred[i])

@m.Constraint(m.I)
def a_const(m, i):
    return m.a[i] == m.ai[1]  + m.ai[2]*m.Cext_net_pred[i]

@m.Constraint(m.I)
def b_const(m, i):
    return m.b[i] == m.bi[1] + m.bi[2]*m.logCext_net_pred[i]

@m.Constraint(m.I)
def Cext_net_pred_constraint(m, i):
    return m.Cext_net_pred[i] == m.C_ex[i] - m.ai[3]*m.CMn_fd[i] - m.ai[4]*m.CCo_fd[i]  -m.ai[5]*m.CCu_fd[i] - m.ai[6]*m.CNi_fd[i]

@m.Constraint(m.I)
def logD_scaled_pred_constraint(m, i):
    return m.logD_scaled_pred[i] == m.a[i]*m.pH[i] + m.b[i]
@m.Objective(sense = pyo.minimize)
def objective_function(m):
    return sum((m.logD_scaled_pred[i] - m.logD[i])**2 for i in m.I)

assert(mstat.degrees_of_freedom(m) == 8)

solver = pyo.SolverFactory('ipopt_v2')
solver.options['halt_on_ampl_error'] = 'yes'

results = solver.solve(m, tee=True, symbolic_solver_labels=True)
# Out:
# Ipopt 3.13.2: halt_on_ampl_error=yes
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      648
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      144
#
# Total number of variables............................:      188
#                      variables with only lower bounds:        4
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      180
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.7771508e+00 9.99e-01 4.01e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.2172424e+00 4.48e-01 5.07e+00  -1.7 8.12e-01   0.0 1.65e-01 1.00e+00h  1
#    2  1.7686098e+00 3.08e-01 3.40e+00  -1.7 5.14e-01  -0.5 8.41e-01 3.50e-01h  1
#    3  1.6070090e+00 1.33e-01 1.15e+00  -1.7 6.15e-01  -1.0 1.00e+00 6.95e-01h  1
#    4  1.5793484e+00 1.89e+00 2.09e+00  -1.7 5.96e+00    -  1.71e-01 5.00e-01f  2
#    5  1.6724955e+00 5.72e-01 3.34e+00  -1.7 1.07e+00  -0.5 1.00e+00 6.25e-01h  1
#    6  1.4558250e+00 1.96e-01 1.24e+00  -1.7 2.43e+00    -  1.00e+00 5.74e-01h  1
#    7  1.1583378e+00 5.44e-01 5.51e-01  -1.7 1.72e+00    -  1.00e+00 1.00e+00h  1
#    8  1.2260293e+00 3.57e-01 1.81e-01  -1.7 1.09e+00    -  1.00e+00 1.00e+00h  1
#    9  1.2094127e+00 3.12e-01 4.86e-02  -1.7 7.40e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1
#   34  1.1867042e+00 8.15e-02 1.25e-02  -8.6 6.26e+05    -  1.00e+00 1.00e+00h  1
#   35  1.1867042e+00 7.95e-02 1.28e-02  -8.6 1.25e+06    -  1.00e+00 1.00e+00h  1
#   36  1.1867042e+00 8.35e-02 1.22e-02  -8.6 2.50e+06    -  1.00e+00 1.00e+00h  1
#   37  1.1867042e+00 7.55e-02 1.35e-02  -8.6 5.01e+06    -  1.00e+00 1.00e+00h  1
#   38  1.1867042e+00 3.35e-02 2.26e-02  -8.6 1.00e+07    -  1.00e+00 1.00e+00H  1
#   39  1.1867042e+00 4.25e-01 5.45e-03  -8.6 2.70e+07    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  1.1867042e+00 1.11e-16 1.30e-10  -8.6 1.18e-08  -2.0 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 40
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1867042451160237e+00    1.1867042451160237e+00
# Dual infeasibility......:   1.2960616174034767e-10    1.2960616174034767e-10
# Constraint violation....:   1.1102230246251565e-16    1.1102230246251565e-16
# Complementarity.........:   2.5059035596800618e-09    2.5059035596800618e-09
# Overall NLP error.......:   2.5059035596800618e-09    2.5059035596800618e-09
#
#
# Number of objective function evaluations             = 45
# Number of objective gradient evaluations             = 41
# Number of equality constraint evaluations            = 45
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 41
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 40
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.062
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.

# %%
import matplotlib.pyplot as plt

plt.plot(np.array(m.logD[:]())*1.0812, np.array(m.logD_scaled_pred[:]())*1.0812, 'o')
plt.plot(np.array(m.logD[:]())*1.0812, np.array(m.logD[:]())*1.0812)

# %% [markdown]
# # Residual plots (for a = a1 + resid)

# %%
n_data = df.shape[0]

from idaes.core.util import model_statistics as mstat
import pyomo.environ as pyo
import numpy as np

m = pyo.ConcreteModel()

m.I = pyo.RangeSet(0, n_data-1)

# Input data vars
m.pH = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.C_ex = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CMn_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CCo_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CNi_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CCu_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)

# Output variable
m.logD = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)


# Parameters
n_a = 6
n_b = 2
m.a_set = pyo.Set(initialize = np.arange(1, n_a+1))
m.b_set = pyo.Set(initialize = np.arange(1, n_b+1))


m.ai = pyo.Var(m.a_set, domain=pyo.Reals, initialize=0.0)
m.bi = pyo.Var(m.b_set, domain=pyo.Reals, initialize=0.0)


name_mapper = {
    'pH_scaled': m.pH,
    '[D2EHPA] _scaled': m.C_ex,
    '[Mn] (mol/L)_scaled': m.CMn_fd,
    '[Co] (mol/L)_scaled': m.CCo_fd,
    '[Ni] (mol/L)_scaled': m.CNi_fd,
    '[Cu] (mol/L)_scaled': m.CCu_fd,
    'log D (obs)_scaled': m.logD
}

# Initialize input variables
for col in name_mapper.keys():
    for i in df.index:
        name_mapper[col][i].fix(df[col][i])

# Model variales

m.logD_scaled_pred =  pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.Cext_net_pred = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.logCext_net_pred = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)

m.a = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.b = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)

# Residual variable
m.res = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)


for i in range(3,7):
    m.ai[i].bounds = (0, None)

# Constraints

@m.Constraint(m.I)
def logCext_net_pred_constraint(m, i):
    return 10**(m.logCext_net_pred[i]) == m.Cext_net_pred[i]

@m.Constraint(m.I)
def a_const(m, i):
    return m.a[i] == m.ai[1]  + m.res[i]#m.ai[2]*m.Cext_net_pred[i]

@m.Constraint(m.I)
def b_const(m, i):
    return m.b[i] == m.bi[1] + m.bi[2]*m.logCext_net_pred[i]

@m.Constraint(m.I)
def Cext_net_pred_constraint(m, i):
    return m.Cext_net_pred[i] == m.C_ex[i] - m.ai[3]*m.CMn_fd[i] - m.ai[4]*m.CCo_fd[i]  -m.ai[5]*m.CCu_fd[i] - m.ai[6]*m.CNi_fd[i]

@m.Constraint(m.I)
def logD_scaled_pred_constraint(m, i):
    return m.logD_scaled_pred[i] == m.a[i]*m.pH[i] + m.b[i]
@m.Objective(sense = pyo.minimize)
def objective_function(m):
    return sum((m.logD_scaled_pred[i] - m.logD[i])**2 for i in m.I)

print(mstat.degrees_of_freedom(m))

solver = pyo.SolverFactory('ipopt_v2')
solver.options['halt_on_ampl_error'] = 'no'

results = solver.solve(m, tee=True, symbolic_solver_labels=True)
# Out:
# 43
# Ipopt 3.13.2: halt_on_ampl_error=no
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      612
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      108
#
# Total number of variables............................:      223
#                      variables with only lower bounds:        4
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      180
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.7771508e+00 1.00e+00 5.44e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.7377814e+00 8.90e-01 1.10e+00  -1.7 4.06e+01  -2.0 5.71e-02 1.17e-01h  1
#    2  9.9254512e-01 5.71e-01 4.45e+00  -1.7 1.51e+00  -0.7 3.68e-01 1.00e+00f  1
#    3  1.2105901e+00 5.60e-01 2.99e+00  -1.7 6.61e+00  -0.2 1.00e+00 4.64e-01h  1
#    4  9.5232009e-01 5.67e-01 2.39e+00  -1.7 1.19e+00   0.2 1.00e+00 7.60e-01h  1
#    5  4.4292252e-01 1.39e-01 1.38e+00  -1.7 4.42e-01  -0.3 1.00e+00 9.24e-01h  1
#    6  4.4955171e-02 3.48e-02 4.42e-01  -1.7 6.12e-01  -0.8 1.00e+00 1.00e+00h  1
#    7  1.0222836e-03 1.03e-02 9.93e-02  -1.7 1.69e-01  -1.3 1.00e+00 1.00e+00h  1
#    8  9.0390543e-06 7.39e-04 9.54e-03  -2.5 5.14e-02  -1.7 1.00e+00 1.00e+00h  1
#    9  4.3793182e-08 8.04e-05 3.73e-04  -3.8 1.23e-02  -2.2 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.9285569e-11 2.85e-07 2.44e-06  -5.7 8.78e-04  -2.7 1.00e+00 1.00e+00h  1
#   11  9.9880303e-16 3.53e-12 8.08e-09  -8.6 1.16e-05  -3.2 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 11
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.9880303402967232e-16    9.9880303402967232e-16
# Dual infeasibility......:   8.0760730622413565e-09    8.0760730622413565e-09
# Constraint violation....:   3.5270675269316598e-12    3.5270675269316598e-12
# Complementarity.........:   2.8320752910203483e-09    2.8320752910203483e-09
# Overall NLP error.......:   8.0760730622413565e-09    8.0760730622413565e-09
#
#
# Number of objective function evaluations             = 12
# Number of objective gradient evaluations             = 12
# Number of equality constraint evaluations            = 12
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 12
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 11
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.025
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.

# %%
@np.vectorize
def f(Cext):
    return -1 *Cext

Cext_range = np.linspace(np.array(m.C_ex[:]()).min(), np.array(m.Cext_net_pred[:]()).max(), 20)

plt.plot(m.Cext_net_pred[:](), m.res[:](), 'o')
plt.plot(Cext_range, f(Cext_range))
plt.xlabel('Cext_net')
plt.ylabel('resid')
plt.show()
