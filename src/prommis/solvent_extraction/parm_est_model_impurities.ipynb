# %%
import pandas as pd
from idaes.core.solvers import get_solver
from pyomo.environ import ConcreteModel, RangeSet, Var, log10, minimize, Constraint

# %%
df = pd.read_excel("data for parmest.xlsx", sheet_name = "impurities new")
index = df.shape[0]
idx_list = RangeSet(0,index-1)
print(df)
# Out:
#    dosage    pH   logD Sc   logD Fe   logD Al   logD Ca  w_Sc  w_Fe  w_Al  \
# 0       1  0.50  0.378902 -0.558804 -0.220183  0.288871     1     1     1
# 1       2  0.50  0.747303 -0.256427 -0.096195  0.418140     1     1     1
# 2       3  0.50  0.817726 -0.120069 -0.010486  0.472605     1     1     1
# 3       4  0.50  0.947321  0.072104  0.159701  0.528951     1     1     1
# 4       5  0.50  1.003111  0.276456  0.241318  0.633754     1     1     1
# 5       2  0.19  0.201962  0.733989  0.022411  0.374677     1     1     1
# 6       2  0.50  0.767898 -0.261729 -0.090733  0.418664     1     1     1
# 7       2  0.99  1.224348 -0.609596 -0.234372  0.467219     1     1     1
# 8       2  1.49  1.780253 -0.652304 -0.527148  0.602364     1     1     1
# 9       2  1.79  1.907405 -1.574557 -0.562191  0.848827     1     1     1
#
#    w_Ca   E Sc   E Fe   E Al   E Ca
# 0     1  44.37   8.43  16.72  39.33
# 1     1  65.07  15.59  21.08  46.61
# 2     1  68.66  20.18  24.55  49.74
# 3     1  74.70  28.24  32.50  52.98
# 4     1  77.05  38.65  36.75  58.92
# 5     1  34.67  64.37  25.98  44.13
# 6     1  66.14  15.43  21.29  46.64
# 7     1  84.82   7.57  16.27  49.43
# 8     1  95.26   6.91   9.01  57.16
# 9     1  96.42   0.88   8.37  70.18

# %%
Element_list = ['Fe','Al','Sc','Ca']

# %%
m = ConcreteModel()

m.pH = Var(idx_list)
m.dosage = Var(idx_list)
# m.logD_exp = Var(idx_list, Element_list)
m.logD_model = Var(idx_list, Element_list)
m.E_exp = Var(idx_list, Element_list)
m.E_model = Var(idx_list, Element_list, bounds=(0, 100))
m.D_model = Var(idx_list, Element_list, bounds=(0, 1e5))


for i in idx_list:
    m.pH[i].fix(df['pH'][i])
    m.dosage[i].fix(df['dosage'][i])
    for e in Element_list:
        # m.logD_exp[i,e].fix(df[f'logD {e}'][i])
        m.E_exp[i, e].fix(df[f"E {e}"][i])

variable_list = [1,2]

# m.a = Var(variable_list, Element_list, initialize = 0.1)
# m.b = Var(variable_list, Element_list, initialize = 0.1)
m.a = Var(variable_list, Element_list, initialize=0.1, bounds=lambda m, i, e: (0, None) if i == 2 else (None, None))
m.b = Var(variable_list, Element_list, initialize=0.1, bounds=lambda m, i, e: (0, None) if i == 2 else (None, None))

# for e in Element_list:
#     m.b[2,e].set_lb(0)

@m.Constraint(idx_list, Element_list)
def logD_model_rule(m, i, e):
    if df.loc[i, f"w_{e}"] == 0:
        return Constraint.Skip
    else:
        return m.logD_model[i, e] == (m.a[1, e] + m.a[2, e] * m.dosage[i]) * m.pH[i] + (
            m.b[1, e] + m.b[2, e] * log10(m.dosage[i])
        )


@m.Constraint(idx_list, Element_list)
def D_model_rule(m, i, e):
    if df.loc[i, f"w_{e}"] == 0:
        return Constraint.Skip
    else:
        return 10 ** m.logD_model[i, e] == m.D_model[i, e]


@m.Constraint(idx_list, Element_list)
def E_model_rule(m, i, e):
    if df.loc[i, f"w_{e}"] == 0:
        return Constraint.Skip
    else:
        return m.E_model[i, e] * ((m.D_model[i, e] + 1)) == m.D_model[i, e] * 100


for e in Element_list:
    for i in idx_list:
        if df.loc[i, f"w_{e}"] == 0:
            m.E_model[i, e].fix(1e-7)
            m.D_model[i, e].fix(1e-7)
            m.logD_model[i, e].fix(0)


@m.Expression()
def SSE(m):
    return sum(
        ((m.E_exp[i, e] - m.E_model[i, e]) ** 2)
        for i in idx_list
        for e in Element_list
        if df.loc[i, f"w_{e}"] == 1
    )


@m.Objective(sense=minimize)
def objective_rule(m):
    return m.SSE

solver=get_solver('ipopt_v2')
solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2: linear_solver="ma57"
# max_iter=200
# nlp_scaling_method="gradient-based"
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      356
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      120
#
# Total number of variables............................:      136
#                      variables with only lower bounds:        8
#                 variables with lower and upper bounds:       80
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      120
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  9.3551312e+04 9.90e-01 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  9.1391047e+04 3.73e-01 4.48e+03  -1.0 1.17e+00    -  9.18e-03 9.84e-01f  1
#    2  8.4144071e+04 3.51e-01 4.20e+03  -1.0 9.62e+01    -  1.26e-02 6.20e-02f  1
#    3  6.4334093e+04 2.42e+00 3.60e+03  -1.0 9.60e+01    -  4.46e-02 1.41e-01f  1
#    4  4.7934266e+04 4.31e+00 3.08e+03  -1.0 8.27e+01    -  9.97e-02 1.44e-01f  1
#    5  2.0936013e+04 1.73e+01 1.98e+03  -1.0 7.15e+01    -  1.51e-01 3.60e-01f  1
#    6  3.8830696e+03 6.43e+01 9.66e+02  -1.0 4.80e+01    -  5.21e-01 6.73e-01f  1
#    7  2.6902923e+03 9.91e+01 1.42e+03  -1.0 5.93e+01    -  3.21e-01 2.30e-01f  1
#    8  2.6815245e+03 5.49e+01 1.75e+04  -1.0 1.08e+01   2.0 8.57e-03 1.00e+00f  1
#    9  2.2862043e+03 3.72e+01 1.17e+04  -1.0 1.29e+01    -  3.15e-01 3.31e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.9469432e+03 9.84e+00 5.38e+03  -1.0 1.70e+01    -  7.17e-02 7.76e-01f  1
#   11  1.5785217e+03 1.01e+00 4.28e+02  -1.0 4.88e+00    -  9.37e-01 1.00e+00f  1
#   12  1.3084553e+03 1.07e+00 3.08e+02  -1.0 1.14e+01    -  6.46e-01 3.10e-01f  1
#   13  1.3011682e+03 1.06e+00 8.40e+02  -1.0 1.27e+01    -  4.66e-01 7.61e-03f  1
#   14  1.2726980e+03 1.06e+00 7.38e+03  -1.0 5.13e+00    -  9.91e-01 6.82e-02f  1
#   15  9.2736283e+02 1.47e+01 1.40e+02  -1.0 5.31e+00    -  1.00e+00 1.00e+00f  1
#   16  7.1857938e+02 2.16e+01 3.33e+03  -1.0 1.39e+01    -  1.00e+00 6.99e-01f  1
#   17  5.2437040e+02 2.38e+01 5.68e+01  -1.0 2.02e+01    -  1.00e+00 1.00e+00f  1
#   18  4.3580828e+02 1.21e+01 3.04e+03  -1.0 2.64e+01    -  5.45e-01 6.67e-01f  1
#   19  3.4344309e+02 2.19e+00 6.09e+05  -1.0 1.60e+01    -  1.10e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  3.1544258e+02 1.32e+00 2.46e+05  -1.0 2.84e+00    -  1.00e+00 4.00e-01f  1
#   21  2.6903676e+02 4.39e-01 2.93e+06  -1.0 2.68e+00    -  9.25e-02 1.00e+00f  1
#   22  2.5077730e+02 4.15e-01 1.38e+01  -1.0 2.41e+00    -  1.00e+00 1.00e+00f  1
#   23  2.5616039e+02 3.58e-01 9.74e+04  -1.7 2.10e+00    -  5.81e-01 1.00e+00h  1
#   24  2.4947124e+02 1.47e-01 1.71e+05  -1.7 1.38e+00    -  9.89e-02 1.00e+00f  1
#   25  2.4909163e+02 5.46e-03 4.24e-01  -1.7 2.90e-01    -  1.00e+00 1.00e+00h  1
#   26  2.4908358e+02 1.08e-04 3.95e-03  -1.7 3.83e-02    -  1.00e+00 1.00e+00h  1
#   27  2.4904089e+02 1.92e-05 9.99e+00  -3.8 3.65e-02    -  9.95e-01 1.00e+00f  1
#   28  2.4904059e+02 8.38e-07 1.37e-04  -3.8 7.61e-03    -  1.00e+00 1.00e+00h  1
#   29  2.4904031e+02 7.48e-09 1.26e-06  -5.7 7.19e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  2.4904030e+02 1.82e-12 1.50e-10  -7.0 7.84e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 30
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.2914348871407748e+02    2.4904030363622701e+02
# Dual infeasibility......:   1.5011591969482652e-10    2.8948353953950345e-10
# Constraint violation....:   1.8189894035458565e-12    1.8189894035458565e-12
# Complementarity.........:   9.1018110752259864e-08    1.7551932477465791e-07
# Overall NLP error.......:   9.1018110752259864e-08    1.7551932477465791e-07
#
#
# Number of objective function evaluations             = 31
# Number of objective gradient evaluations             = 31
# Number of equality constraint evaluations            = 31
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 31
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 30
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.030
# Total CPU secs in NLP function evaluations           =      0.003
#
# EXIT: Optimal Solution Found.
# {'Problem': [{'Lower bound': None, 'Upper bound': 249.040303636227, 'Number of objectives': 1, 'Number of constraints': nan, 'Number of variables': nan, 'Sense': 'minimize'}], 'Solver': [{'Status': 'ok', 'Termination condition': 'optimal', 'Termination message': 'TerminationCondition.convergenceCriteriaSatisfied'}], 'Solution': [OrderedDict({'number of solutions': 0, 'number of solutions displayed': 0})]}

# %%
m.a.pprint()
m.b.pprint()
# Out:
# a : Size=8, Index={1, 2}*{Fe, Al, Sc, Ca}
#     Key       : Lower : Value               : Upper : Fixed : Stale : Domain
#     (1, 'Al') :  None : -0.8089428110750763 :  None : False : False :  Reals
#     (1, 'Ca') :  None :  0.1045958110258244 :  None : False : False :  Reals
#     (1, 'Fe') :  None :  -3.892174275859373 :  None : False : False :  Reals
#     (1, 'Sc') :  None :  1.3354330923183073 :  None : False : False :  Reals
#     (2, 'Al') :     0 : 0.21674455926658126 :  None : False : False :  Reals
#     (2, 'Ca') :     0 : 0.07923412219261124 :  None : False : False :  Reals
#     (2, 'Fe') :     0 :   0.307572990853262 :  None : False : False :  Reals
#     (2, 'Sc') :     0 :                 0.0 :  None : False : False :  Reals
# b : Size=8, Index={1, 2}*{Fe, Al, Sc, Ca}
#     Key       : Lower : Value                : Upper : Fixed : Stale : Domain
#     (1, 'Al') :  None : -0.39813603721557794 :  None : False : False :  Reals
#     (1, 'Ca') :  None : -0.27090534818916984 :  None : False : False :  Reals
#     (1, 'Fe') :  None :   0.8073953035417731 :  None : False : False :  Reals
#     (1, 'Sc') :  None :  -0.7369160031783826 :  None : False : False :  Reals
#     (2, 'Al') :     0 :  0.04580550200621134 :  None : False : False :  Reals
#     (2, 'Ca') :     0 :  0.22679127179944839 :  None : False : False :  Reals
#     (2, 'Fe') :     0 :   0.2258546811007163 :  None : False : False :  Reals
#     (2, 'Sc') :     0 :   0.8977612654892466 :  None : False : False :  Reals

# %%
no_data = 0
for e in Element_list:
    no_data +=(df[f'w_{e}'] == 1).sum()
no_data
# Out:
# np.int64(79)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_percentage_error

for e in Element_list:
    x = [m.E_exp[i, e]() for i in idx_list if df.loc[i, f"w_{e}"] == 1]
    y = [m.E_model[i, e]() for i in idx_list if df.loc[i, f"w_{e}"] == 1]
    # x_ideal = [m.logD_exp[i, e].value for i in idx_list]
    plt.plot(x, x, label='y=x (ideal)', linestyle='-', color='black')
    
    for i in idx_list:
        plt.scatter(x[i], y[i], color='red', label='5% DEHPA 10% TBP')
    plt.xlabel('experiment')
    plt.ylabel('model')
    plt.title(f"{e} logD parity, R^2 = {r2_score(x, y)*100:.2f}%")
    
    plt.show()

# %%
df_parameters = pd.DataFrame(index=Element_list, columns=['a1','a2','b1','b2'])
for e in Element_list:
    df_parameters.loc[e, 'a1'] = m.a[1,e].value
    df_parameters.loc[e, 'a2'] = m.a[2,e].value
    df_parameters.loc[e, 'b1'] = m.b[1,e].value
    df_parameters.loc[e, 'b2'] = m.b[2,e].value

# %%
df_parameters
# Out:
#           a1        a2        b1        b2
# Y   1.923028  0.074853 -2.186904  0.000001
# Ce  0.451805  0.014818  -1.92042  0.000001
# Nd  0.406063       0.0 -1.820107  0.000002
# Sm  0.764036  0.021876 -2.153372  0.008403
# Gd  1.141498  0.000002 -2.407248  0.296711
# Dy  1.689088   0.05774 -2.354474  0.000001

# %%
with pd.ExcelWriter('data for parmest.xlsx', engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
    df_parameters.to_excel(writer, sheet_name='parameter values out dosage')

# %%
for i in RangeSet(0,2):
    for j in RangeSet(0,1):
        print(j+1+2*i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

fig, ax = plt.subplots(3,2,figsize=(8,10),dpi=300)
fig.suptitle("logD Parity Plots for REEs", fontsize=16)
element_dict = dict(zip(RangeSet(1,6),['Y','Ce','Gd','Nd','Sm','Dy']))
text_label = dict(zip(RangeSet(1,6),['a)','b)','c)','d)','e)','f)']))
for a in RangeSet(0,2):
    for b in RangeSet(0,1):
        e = element_dict[b+1+2*a]
        txt_label=text_label[b+1+2*a]
        x = [m.logD_exp[i, e].value*df[f'w_{e}'][i] for i in idx_list]
        y = [m.logD_model[i, e].value*df[f'w_{e}'][i] for i in idx_list]
        x_ideal = [m.logD_exp[i, e].value for i in idx_list]
        ax[a,b].plot(x_ideal, x_ideal, label='y=x (ideal)', linestyle='-', color='black')
        red_points = []
        green_points = []
        for i in idx_list:
            if df[f'w_{e}'][i] == 1:
                if 2 <df['dosage'][i] <5:
                    red_points.append(ax[a,b].scatter(x[i], y[i], color='red', label='5% DEHPA 10% TBP'))
                if df['dosage'][i] < 2:
                    green_points.append(ax[a,b].scatter(x[i], y[i], color='green', label='2% DEHPA 10% TBP'))
        ax[a,b].set(xlabel='experiment',ylabel='model')
        ax[a,b].set_title(f"{e}, $R^2$ = {r2_score(x, y):.4f}")
        ax[a,b].text(0.5, -0.28, txt_label, transform=ax[a,b].transAxes,
                     ha='center', va='center', fontsize=12)
        # Build legend handles/labels manually to avoid duplicates
        handles = [plt.Line2D([], [], color='black', label='y=x (ideal)')]
        if red_points:
            handles.append(plt.Line2D([], [], color='red', marker='o', linestyle='None', label='5% DEHPA 10% TBP'))
        if green_points:
            handles.append(plt.Line2D([], [], color='green', marker='o', linestyle='None', label='2% DEHPA 10% TBP'))
        labels = [h.get_label() for h in handles]
        ax[a,b].legend(handles, labels, fontsize=8)
plt.tight_layout()
