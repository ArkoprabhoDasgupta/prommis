# 3       0.000056      0.000060      0.000060
# 4       0.000024      0.000140      0.000140
# 5       0.000056      0.000060      0.000140
# 6       0.000024      0.000140      0.000060
# 7       0.000056      0.000140      0.000060
# 8       0.000056      0.000060      0.000140
# 9       0.000024      0.000060      0.000140
# 10      0.000024      0.000140      0.000060
# 11      0.000056      0.000140      0.000060
# 12      0.000056      0.000060      0.000140
# 13      0.000024      0.000060      0.000060
# 14      0.000024      0.000140      0.000140
# 15      0.000056      0.000060      0.000060
# 16      0.000024      0.000140      0.000060
# 17      0.000056      0.000060      0.000060
# 18      0.000024      0.000060      0.000060
# 19      0.000024      0.000060      0.000140
# 20      0.000024      0.000060      0.000140
# 21      0.000024      0.000140      0.000140
# 22      0.000056      0.000140      0.000140
# 23      0.000024      0.000060      0.000060
# 24      0.000040      0.000100      0.000100
# 25      0.000040      0.000100      0.000100
# 26      0.000005      0.000100      0.000100
# 27      0.000075      0.000100      0.000100
# 28      0.000040      0.000012      0.000100
# 29      0.000040      0.000189      0.000100
# 30      0.000040      0.000100      0.000012
# 31      0.000040      0.000100      0.000189
# 32      0.000040      0.000100      0.000100
# 33      0.000040      0.000100      0.000100
# 34      0.000040      0.000100      0.000100
# 35      0.000040      0.000100      0.000100
# 36      0.000040      0.000100      0.000100
# 37      0.000040      0.000100      0.000100
# 38      0.000040      0.000100      0.000100
# 39      0.000040      0.000100      0.000100

# %%
df.head()

# Remove rows with NaN values
df = df.dropna()

# Reset index after dropping NaN values
df = df.reset_index(drop=True)
df
# # scale each column by doing df[col] = df[col] / abs(df[col]).max()
for col in df.columns:
    if df[col].dtype in ['float64', 'int64']:
        max_value_ = abs(df[col]).max()
        scaled_column_name = f"{col}_scaled"
        df[scaled_column_name] = df[col] / max_value_
        print(f"Scaled {col} by {max_value_}")


# Remove idx = 31 from data
# Out:
# Scaled pH by 4.51
# Scaled A/O by 2.61
# Scaled [D2EHPA]  by 0.47
# Scaled extraction % by 70.91
# Scaled Dobs by 3.0813008130081303
# Scaled log D (obs) by 1.0812025060113195
# Scaled [Mn] (mol/L) by 0.19
# Scaled [Co] (mol/L) by 7.54e-05
# Scaled [Ni] (mol/L) by 0.00014
# Scaled [Cu] (mol/L) by 0.000189

# %%
df
# Out:
#       pH   A/O  [D2EHPA]   extraction %      Dobs  log D (obs)  [Mn] (mol/L)  \
# 0   3.86  2.00       0.15          6.10  0.129925    -0.886306          0.14
# 1   3.53  1.00       0.35         36.73  0.580528    -0.236177          0.14
# 2   2.59  2.00       0.15          6.33  0.135155    -0.869167          0.14
# 3   2.53  2.00       0.35          7.71  0.167082    -0.777070          0.14
# 4   3.06  1.00       0.35         27.65  0.382170    -0.417743          0.14
# 5   3.54  1.00       0.15         31.68  0.463700    -0.333763          0.06
# 6   2.50  2.00       0.15          5.30  0.111932    -0.951044          0.14
# 7   2.50  2.00       0.35         16.14  0.384927    -0.414621          0.06
# 8   3.54  1.00       0.35         24.71  0.328198    -0.483865          0.14
# 9   2.50  1.00       0.15         14.39  0.168088    -0.774464          0.14
# 10  3.51  2.00       0.15         22.18  0.570033    -0.244100          0.06
# 11  2.56  1.00       0.35         44.25  0.793722    -0.100332          0.06
# 1              0.736842             0.742706             1.000000
# 2              0.736842             0.742706             1.000000
# 3              0.736842             0.742706             0.428571
# 4              0.736842             0.318302             1.000000
# 5              0.315789             0.742706             0.428571
# 6              0.736842             0.318302             1.000000
# 7              0.315789             0.742706             1.000000
# 8              0.736842             0.742706             0.428571
# 9              0.736842             0.318302             0.428571
# 10             0.315789             0.318302             1.000000
# 11             0.315789             0.742706             1.000000
# 12             0.736842             0.742706             0.428571
# 13             0.736842             0.318302             0.428571
# 14             0.315789             0.318302             1.000000
# 15             0.315789             0.742706             0.428571
# 16             0.736842             0.318302             1.000000
# 17             0.315789             0.742706             0.428571
# 18             0.736842             0.318302             0.428571
# 19             0.315789             0.318302             0.428571
# 20             0.315789             0.318302             0.428571
# 21             0.315789             0.318302             1.000000
# 22             0.315789             0.742706             1.000000
# 23             0.315789             0.318302             0.428571
# 24             0.052632             0.530504             0.714286
# 25             1.000000             0.530504             0.714286
# 26             0.526316             0.060875             0.714286
# 27             0.526316             1.000000             0.714286
# 28             0.526316             0.530504             0.082143
# 29             0.526316             0.530504             0.714286
# 30             0.526316             0.530504             0.714286
# 31             0.526316             0.530504             0.714286
# 32             0.526316             0.530504             0.714286
# 33             0.526316             0.530504             0.714286
# 34             0.526316             0.530504             0.714286
# 35             0.526316             0.530504             0.714286
# 36             0.526316             0.530504             0.714286
# 37             0.526316             0.530504             0.714286
#
#     [Cu] (mol/L)_scaled
# 0              0.740741
# 1              0.317460
# 2              0.740741
# 3              0.317460
# 4              0.740741
# 5              0.740741
# 6              0.317460
# 7              0.317460
# 8              0.740741
# 9              0.740741
# 10             0.317460
# 11             0.317460
# 12             0.740741
# 13             0.317460
# 14             0.740741
# 15             0.317460
# 16             0.317460
# 17             0.317460
# 18             0.317460
# 19             0.740741
# 20             0.740741
# 21             0.740741
# 22             0.740741
# 23             0.317460
# 24             0.529101
# 25             0.529101
# 26             0.529101
# 27             0.529101
# 28             0.529101
# 29             0.060847
# 30             1.000000
# 31             0.529101
# 32             0.529101
# 33             0.529101
# 34             0.529101
# 35             0.529101
# 36             0.529101
# 37             0.529101

# %%
n_data = df.shape[0]

from idaes.core.util import model_statistics as mstat
import pyomo.environ as pyo
import numpy as np

m = pyo.ConcreteModel()

m.I = pyo.RangeSet(0, n_data-1)

# Input data vars
m.pH = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.C_ex = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CMn_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CCo_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CNi_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CCu_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)

# Output variable
m.logD = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)


# Parameters
n_a = 6
n_b = 2
m.a_set = pyo.Set(initialize = np.arange(1, n_a+1))
m.b_set = pyo.Set(initialize = np.arange(1, n_b+1))


m.ai = pyo.Var(m.a_set, domain=pyo.Reals, initialize=0.0)
m.bi = pyo.Var(m.b_set, domain=pyo.Reals, initialize=0.0)


name_mapper = {
    'pH_scaled': m.pH,
    '[D2EHPA] _scaled': m.C_ex,
    '[Mn] (mol/L)_scaled': m.CMn_fd,
    '[Co] (mol/L)_scaled': m.CCo_fd,
    '[Ni] (mol/L)_scaled': m.CNi_fd,
    '[Cu] (mol/L)_scaled': m.CCu_fd,
    'log D (obs)_scaled': m.logD
}

# Initialize input variables
for col in name_mapper.keys():
    for i in df.index:
        name_mapper[col][i].fix(df[col][i])

# Model variales

m.logD_scaled_pred =  pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.Cext_net_pred = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.logCext_net_pred = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)

m.a = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.b = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)


for i in range(3,7):
    m.ai[i].bounds = (0, None)

# Constraints

@m.Constraint(m.I)
def logCext_net_pred_constraint(m, i):
    return 10**(m.logCext_net_pred[i]) == m.Cext_net_pred[i]

@m.Constraint(m.I)
def a_const(m, i):
    return m.a[i] == m.ai[1]  + m.ai[2]*m.Cext_net_pred[i]

@m.Constraint(m.I)
def b_const(m, i):
    return m.b[i] == m.bi[1] + m.bi[2]*m.logCext_net_pred[i]

@m.Constraint(m.I)
def Cext_net_pred_constraint(m, i):
    return m.Cext_net_pred[i] == m.C_ex[i] - m.ai[3]*m.CMn_fd[i] - m.ai[4]*m.CCo_fd[i]  -m.ai[5]*m.CCu_fd[i] - m.ai[6]*m.CNi_fd[i]

@m.Constraint(m.I)
def logD_scaled_pred_constraint(m, i):
    return m.logD_scaled_pred[i] == m.a[i]*m.pH[i] + m.b[i]
@m.Objective(sense = pyo.minimize)
def objective_function(m):
    return sum((m.logD_scaled_pred[i] - m.logD[i])**2 for i in m.I)

assert(mstat.degrees_of_freedom(m) == 8)

solver = pyo.SolverFactory('ipopt_v2')
solver.options['halt_on_ampl_error'] = 'no'

results = solver.solve(m, tee=True, symbolic_solver_labels=True)
# Out:
# Ipopt 3.13.2: halt_on_ampl_error=no
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      684
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      152
#
# Total number of variables............................:      198
#                      variables with only lower bounds:        4
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      190
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.3419366e+01 1.00e+00 6.25e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.8180022e+00 1.05e+00 7.45e+00  -1.7 1.31e+00   0.0 1.19e-01 1.00e+00f  1
#    2  4.0618226e+00 6.15e-01 2.06e+00  -1.7 1.97e+00  -0.5 1.00e+00 8.69e-01f  1
#    3  4.1050155e+00 2.56e-01 4.07e+00  -1.7 1.79e+00  -0.1 1.00e+00 3.38e-01h  1
#    4  4.1589326e+00 1.06e+00 1.17e+00  -1.7 2.94e+00  -0.5 1.00e+00 5.00e-01h  2
#    5  4.2060921e+00 1.01e+00 1.08e+00  -1.7 3.37e+00  -1.0 3.57e-01 8.98e-02h  4
#    6  4.1543484e+00 8.80e-01 2.63e+00  -1.7 4.28e-01   0.3 1.00e+00 1.26e-01h  1
#    7  4.1428065e+00 8.51e-02 3.81e-01  -1.7 4.17e-01  -0.2 1.00e+00 1.00e+00f  1
#    8  3.4657291e+00 1.75e-02 2.67e-01  -1.7 1.42e+00    -  1.00e+00 1.00e+00h  1
#    9  3.4673479e+00 8.65e-02 3.29e-02  -1.7 4.81e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.4460414e+00 1.44e-02 6.12e-02  -2.5 3.72e-01    -  8.30e-01 1.00e+00h  1
#   11  3.4332546e+00 2.21e-02 3.62e-03  -2.5 4.67e-01    -  1.00e+00 1.00e+00h  1
#   12  3.4265418e+00 2.85e-03 1.21e-03  -3.8 3.92e-01    -  9.78e-01 1.00e+00h  1
#   13  3.4262226e+00 4.38e-03 4.06e-04  -3.8 3.77e-01    -  1.00e+00 1.00e+00h  1
#   14  3.4262682e+00 1.96e-03 1.18e-04  -3.8 3.06e-01    -  1.00e+00 1.00e+00h  1
#   15  3.4262935e+00 6.47e-04 2.37e-05  -3.8 1.88e-01    -  1.00e+00 1.00e+00h  1
#   16  3.4258572e+00 3.73e-05 3.66e-06  -5.7 4.82e-02    -  1.00e+00 1.00e+00h  1
#   17  3.4258566e+00 2.07e-07 5.70e-09  -5.7 3.59e-03    -  1.00e+00 1.00e+00h  1
#   18  3.4258511e+00 4.14e-10 6.22e-11  -8.6 1.56e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 18
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.4258510717569055e+00    3.4258510717569055e+00
# Dual infeasibility......:   6.2244372850406293e-11    6.2244372850406293e-11
# Constraint violation....:   4.1372794079563846e-10    4.1372794079563846e-10
# Complementarity.........:   2.5550292765947937e-09    2.5550292765947937e-09
# Overall NLP error.......:   2.5550292765947937e-09    2.5550292765947937e-09
#
#
# Number of objective function evaluations             = 28
# Number of objective gradient evaluations             = 19
# Number of equality constraint evaluations            = 28
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 19
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 18
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.038
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.

# %%
import matplotlib.pyplot as plt

plt.plot(np.array(m.logD[:]()), np.array(m.logD_scaled_pred[:]()), 'o')
plt.plot(np.array(m.logD[:]()), np.array(m.logD[:]()))
plt.grid()

# %%
m.ai.pprint()
# Out:
# ai : Size=6, Index=a_set
#     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#       1 :  None : 0.8201779172933245 :  None : False : False :  Reals
#       2 :  None : 0.7695189952458996 :  None : False : False :  Reals
#       3 :     0 :  0.121205253734499 :  None : False : False :  Reals
#       4 :     0 :                0.0 :  None : False : False :  Reals
#       5 :     0 :                0.0 :  None : False : False :  Reals
#       6 :     0 :                0.0 :  None : False : False :  Reals

# %%
m.bi.pprint()
# Out:
# bi : Size=2, Index=b_set
#     Key : Lower : Value              : Upper : Fixed : Stale : Domain
#       1 :  None : -1.248474868822723 :  None : False : False :  Reals
#       2 :  None : 0.0677671073660304 :  None : False : False :  Reals

# %%
df
# Out:
#       pH   A/O  [D2EHPA]   extraction %      Dobs  log D (obs)  [Mn] (mol/L)  \
# 0   3.86  2.00       0.15          6.10  0.129925    -0.886306          0.14
# 1   3.53  1.00       0.35         36.73  0.580528    -0.236177          0.14
# 2   2.59  2.00       0.15          6.33  0.135155    -0.869167          0.14
# 3   2.53  2.00       0.35          7.71  0.167082    -0.777070          0.14
# 4   3.06  1.00       0.35         27.65  0.382170    -0.417743          0.14
# 5   3.54  1.00       0.15         31.68  0.463700    -0.333763          0.06
# 6   2.50  2.00       0.15          5.30  0.111932    -0.951044          0.14
# 7   2.50  2.00       0.35         16.14  0.384927    -0.414621          0.06
# 8   3.54  1.00       0.35         24.71  0.328198    -0.483865          0.14
# 9   2.50  1.00       0.15         14.39  0.168088    -0.774464          0.14
# 10  3.51  2.00       0.15         22.18  0.570033    -0.244100          0.06
# 11  2.56  1.00       0.35         44.25  0.793722    -0.100332          0.06
# 12  2.67  2.00       0.15          5.44  0.115059    -0.939079          0.14
# 13  2.51  1.00       0.35         15.20  0.179245    -0.746552          0.14
# 14  2.52  1.00       0.15         26.03  0.351899    -0.453581          0.06
# 15  3.50  1.00       0.15         51.90  1.079002     0.033022          0.06
# 16  2.51  1.00       0.15         14.11  0.164280    -0.784416          0.14
# 17  3.50  2.00       0.15         37.86  1.218539     0.085839          0.06
# 18  3.51  2.00       0.35         17.41  0.421601    -0.375099          0.14
# 19  3.53  2.00       0.35         60.64  3.081301     0.488734          0.06
# 16             0.736842             0.318302             1.000000
# 17             0.315789             0.742706             0.428571
# 18             0.736842             0.318302             0.428571
# 19             0.315789             0.318302             0.428571
# 20             0.315789             0.318302             0.428571
# 21             0.315789             0.318302             1.000000
# 22             0.315789             0.742706             1.000000
# 23             0.315789             0.318302             0.428571
# 24             0.052632             0.530504             0.714286
# 25             1.000000             0.530504             0.714286
# 26             0.526316             0.060875             0.714286
# 27             0.526316             1.000000             0.714286
# 28             0.526316             0.530504             0.082143
# 29             0.526316             0.530504             0.714286
# 30             0.526316             0.530504             0.714286
# 31             0.526316             0.530504             0.714286
# 32             0.526316             0.530504             0.714286
# 33             0.526316             0.530504             0.714286
# 34             0.526316             0.530504             0.714286
# 35             0.526316             0.530504             0.714286
# 36             0.526316             0.530504             0.714286
# 37             0.526316             0.530504             0.714286
#
#     [Cu] (mol/L)_scaled
# 0              0.740741
# 1              0.317460
# 2              0.740741
# 3              0.317460
# 4              0.740741
# 5              0.740741
# 6              0.317460
# 7              0.317460
# 8              0.740741
# 9              0.740741
# 10             0.317460
# 11             0.317460
# 12             0.740741
# 13             0.317460
# 14             0.740741
# 15             0.317460
# 16             0.317460
# 17             0.317460
# 18             0.317460
# 19             0.740741
# 20             0.740741
# 21             0.740741
# 22             0.740741
# 23             0.317460
# 24             0.529101
# 25             0.529101
# 26             0.529101
# 27             0.529101
# 28             0.529101
# 29             0.060847
# 30             1.000000
# 31             0.529101
# 32             0.529101
# 33             0.529101
# 34             0.529101
# 35             0.529101
# 36             0.529101
# 37             0.529101

# %% [markdown]
# # Residual plots (for a = a1 + resid)

# %%
n_data = df.shape[0]

from idaes.core.util import model_statistics as mstat
import pyomo.environ as pyo
import numpy as np

m = pyo.ConcreteModel()

m.I = pyo.RangeSet(0, n_data-1)

# Input data vars
m.pH = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.C_ex = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CMn_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CCo_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CNi_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.CCu_fd = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)

# Output variable
m.logD = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)


# Parameters
n_a = 6
n_b = 2
m.a_set = pyo.Set(initialize = np.arange(1, n_a+1))
m.b_set = pyo.Set(initialize = np.arange(1, n_b+1))


m.ai = pyo.Var(m.a_set, domain=pyo.Reals, initialize=0.0)
m.bi = pyo.Var(m.b_set, domain=pyo.Reals, initialize=0.0)


name_mapper = {
    'pH_scaled': m.pH,
    '[D2EHPA] _scaled': m.C_ex,
    '[Mn] (mol/L)_scaled': m.CMn_fd,
    '[Co] (mol/L)_scaled': m.CCo_fd,
    '[Ni] (mol/L)_scaled': m.CNi_fd,
    '[Cu] (mol/L)_scaled': m.CCu_fd,
    'log D (obs)_scaled': m.logD
}

# Initialize input variables
for col in name_mapper.keys():
    for i in df.index:
        name_mapper[col][i].fix(df[col][i])

# Model variales

m.logD_scaled_pred =  pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.Cext_net_pred = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.logCext_net_pred = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)

m.a = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)
m.b = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)

# Residual variable
m.res = pyo.Var(m.I, domain=pyo.Reals, initialize=0.0)


for i in range(3,7):
    m.ai[i].bounds = (0, None)

# Constraints

@m.Constraint(m.I)
def logCext_net_pred_constraint(m, i):
    return 10**(m.logCext_net_pred[i]) == m.Cext_net_pred[i]

@m.Constraint(m.I)
def a_const(m, i):
    return m.a[i] == m.ai[1]  + m.res[i]#m.ai[2]*m.Cext_net_pred[i]

@m.Constraint(m.I)
def b_const(m, i):
    return m.b[i] == m.bi[1] + m.bi[2]*m.logCext_net_pred[i]

@m.Constraint(m.I)
def Cext_net_pred_constraint(m, i):
    return m.Cext_net_pred[i] == m.C_ex[i] - m.ai[3]*m.CMn_fd[i] - m.ai[4]*m.CCo_fd[i]  -m.ai[5]*m.CCu_fd[i] - m.ai[6]*m.CNi_fd[i]

@m.Constraint(m.I)
def logD_scaled_pred_constraint(m, i):
    return m.logD_scaled_pred[i] == m.a[i]*m.pH[i] + m.b[i]
@m.Objective(sense = pyo.minimize)
def objective_function(m):
    return sum((m.logD_scaled_pred[i] - m.logD[i])**2 for i in m.I)

print(mstat.degrees_of_freedom(m))

solver = pyo.SolverFactory('ipopt_v2')
solver.options['halt_on_ampl_error'] = 'no'

results = solver.solve(m, tee=True, symbolic_solver_labels=True)
# Out:
# 45
# Ipopt 3.13.2: halt_on_ampl_error=no
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      646
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      114
#
# Total number of variables............................:      235
#                      variables with only lower bounds:        4
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      190
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.3419366e+01 1.00e+00 8.20e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.4310406e+00 4.46e-01 5.82e+00  -1.7 8.29e-01   0.0 1.47e-01 1.00e+00f  1
#    2  2.4014955e+00 3.48e-01 3.68e+00  -1.7 1.33e+00  -0.5 1.95e-01 3.56e-01f  1
#    3  1.3138854e+00 2.19e-01 3.29e+00  -1.7 1.58e+00  -1.0 1.00e+00 3.46e-01f  1
#    4  5.6123022e-01 2.10e-01 2.21e+00  -1.7 1.28e+00  -1.4 1.00e-01 3.61e-01f  1
#    5  3.1749068e-01 1.29e-01 1.29e+00  -1.7 7.05e-01  -1.0 1.00e+00 3.14e-01f  1
#    6  1.8130985e-02 5.22e-02 3.33e-01  -1.7 5.96e-01  -1.5 1.00e+00 8.02e-01f  1
#    7  2.3208799e-04 3.23e-01 4.33e-02  -1.7 7.19e-01  -2.0 1.00e+00 1.00e+00h  1
#    8  4.1563071e-07 2.59e-02 4.53e-03  -1.7 4.16e-01  -2.4 1.00e+00 1.00e+00h  1
#    9  2.1564801e-09 7.29e-05 9.29e-05  -3.8 1.16e-02  -2.9 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.0545454e-14 2.83e-08 3.59e-07  -5.7 5.40e-04  -3.4 1.00e+00 1.00e+00h  1
#   11  1.3435900e-19 1.34e-12 4.36e-10  -8.6 3.19e-06  -3.9 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 11
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.3435900002196303e-19    1.3435900002196303e-19
# Dual infeasibility......:   4.3554688511429758e-10    4.3554688511429758e-10
# Constraint violation....:   1.3394563236346357e-12    1.3394563236346357e-12
# Complementarity.........:   2.5437237979327362e-09    2.5437237979327362e-09
# Overall NLP error.......:   2.5437237979327362e-09    2.5437237979327362e-09
#
#
# Number of objective function evaluations             = 12
# Number of objective gradient evaluations             = 12
# Number of equality constraint evaluations            = 12
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 12
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 11
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.026
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.

# %%
@np.vectorize
def f(Cext):
    return -1 *Cext

Cext_range = np.linspace(np.array(m.C_ex[:]()).min(), np.array(m.Cext_net_pred[:]()).max(), 20)

plt.plot(m.Cext_net_pred[:](), m.res[:](), 'o')
plt.plot(Cext_range, f(Cext_range))
plt.xlabel('Cext_net')
plt.ylabel('resid')
plt.show()
