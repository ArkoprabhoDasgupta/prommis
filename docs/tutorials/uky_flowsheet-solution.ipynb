# %% [markdown]
# # UKy Flowsheet Tutorial
#
# This tutorial will show how to build, initialize, and simulate the West Kentucky No.13 Coal Refuse flowsheet. The inputs into this flowsheet are case study-specific, so users should not expect the flowsheet to solve if the values are significantly altered.
#
# - Useful Links:
#     - Public Github Repository: https://github.com/prommis/prommis/tree/main
#     - UKy Flowsheet Code: https://github.com/prommis/prommis/blob/main/src/prommis/uky/uky_flowsheet.py
#
# ![uky_flowsheet.png](./uky_flowsheet.png)

# %% [markdown]
# ## Step 1: Import the necessary tools

# %%
# Import the essentials from Pyomo
from pyomo.environ import (
    ConcreteModel,
    Constraint,
    SolverFactory,
    Suffix,
    TransformationFactory,
    Var,
    units,
)
from pyomo.network import Arc, SequentialDecomposition
from pyomo.util.check_units import assert_units_consistent

# Import the essentials from IDAES
from idaes.models.properties.modular_properties.base.generic_property import (
    GenericParameterBlock,
)
from idaes.models_extra.power_generation.properties.natural_gas_PR import (
    EosType,
    get_prop,
)
from idaes.core import (
    FlowDirection,
    FlowsheetBlock,
    MaterialBalanceType,
    MomentumBalanceType,
)
import idaes.logger as idaeslog

# Import scaling, initializtion, and diagnostic tools from IDAES
from idaes.core.scaling.scaling_base import ScalerBase
from idaes.core.initialization import BlockTriangularizationInitializer
from idaes.core.util.initialization import propagate_state
from idaes.core.util.model_diagnostics import DiagnosticsToolbox
from idaes.core.util.model_statistics import degrees_of_freedom as dof

# Import unit models from IDAES
from idaes.models.unit_models.feed import Feed, FeedInitializer
from idaes.models.unit_models.mixer import (
    Mixer,
    MixingType,
    MomentumMixingType,
    MixerInitializer,
)
from idaes.models.unit_models.product import Product, ProductInitializer
from idaes.models.unit_models.separator import (
    EnergySplittingType,
    Separator,
    SplittingType,
    SeparatorInitializer,
)
from idaes.models.unit_models.solid_liquid import SLSeparator
from idaes.models.unit_models.translator import Translator

# Import the UKy-specific unit and property models
from prommis.leaching.leach_train import LeachingTrain, LeachingTrainInitializer
from prommis.leaching.leach_reactions import CoalRefuseLeachingReactions
from prommis.leaching.leach_solids_properties import CoalRefuseParameters
from prommis.leaching.leach_solution_properties import LeachSolutionParameters
from prommis.precipitate.precipitate_liquid_properties import AqueousParameter
from prommis.precipitate.precipitate_solids_properties import PrecipitateParameters
from prommis.precipitate.precipitator import Precipitator
from prommis.roasting.ree_oxalate_roaster import REEOxalateRoaster
from prommis.solvent_extraction.ree_og_distribution import REESolExOgParameters
from prommis.solvent_extraction.solvent_extraction import (
    SolventExtraction,
    SolventExtractionInitializer,
)
from prommis.solvent_extraction.solvent_extraction_reaction_package import (
    SolventExtractionReactions,
)
from prommis.solvent_extraction.translator_leach_precip import TranslatorLeachPrecip

# Set up logger
_log = idaeslog.getLogger(__name__)

# %% [markdown]
# ## Step 2 Flowsheet building

# %% [markdown]
# ### Step 2.1: Create Flowsheet
# Start by creating a pyomo model and a flowsheet.

# %%
m = ConcreteModel()

m.fs = FlowsheetBlock(dynamic=False)

# %% [markdown]
# Then begin assembling the unit, property, and reaction models section-by-section. These variables will be created in chronological order - beginning with the leaching section of the flowsheet and concluding with the product roasting section.

# %% [markdown]
# ### Step 2.2 Create variables for the leaching section
# Specify the necessary unit, property, and reaction models for the leaching section.

# %%
# Leaching property models
m.fs.leach_soln = LeachSolutionParameters()
m.fs.coal = CoalRefuseParameters()

# Leaching reaction model
m.fs.leach_rxns = CoalRefuseLeachingReactions()

# Leaching unit model
m.fs.leach = LeachingTrain(
    number_of_tanks=2,
    liquid_phase={
        "property_package": m.fs.leach_soln,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    solid_phase={
        "property_package": m.fs.coal,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    reaction_package=m.fs.leach_rxns,
)

# Solid-liquid separator used to approximate a filter press
m.fs.sl_sep1 = SLSeparator(
    solid_property_package=m.fs.coal,
    liquid_property_package=m.fs.leach_soln,
    material_balance_type=MaterialBalanceType.componentTotal,
    # Ignore momentum balance since the property package does not have pressure or momentum terms
    momentum_balance_type=MomentumBalanceType.none,
    # Ignore energy split basis since the property package does not have temperature terms
    energy_split_basis=EnergySplittingType.none,
)

# Recycle loop mixer
m.fs.leach_mixer = Mixer(
    property_package=m.fs.leach_soln,
    num_inlets=3,
    inlet_list=["load_recycle", "scrub_recycle", "feed"],
    material_balance_type=MaterialBalanceType.componentTotal,
    # Ignore mixing type since the property package does not have enthalpy terms
    energy_mixing_type=MixingType.none,
    # Ignore momentum mixing since the property package does not have pressure or momentum terms
    momentum_mixing_type=MomentumMixingType.none,
)

# Define inlets into the flowsheet
m.fs.leach_liquid_feed = Feed(property_package=m.fs.leach_soln)
m.fs.leach_solid_feed = Feed(property_package=m.fs.coal)

# Define outlets from the flowsheet
m.fs.leach_filter_cake = Product(property_package=m.fs.coal)
m.fs.leach_filter_cake_liquid = Product(property_package=m.fs.leach_soln)

# %% [markdown]
# ### Step 2.3 Create variables for the solvent extraction section
# Specify the necessary unit, property, and reaction models for the solvent extraction section.

# %%
# Solvent extraction property models
m.fs.prop_o = REESolExOgParameters()
m.fs.reaxn = SolventExtractionReactions()

m.fs.rougher_org_make_up = Feed(property_package=m.fs.prop_o)

m.fs.solex_rougher_load = SolventExtraction(
    number_of_finite_elements=3,
    dynamic=False,
    aqueous_stream={
        "property_package": m.fs.leach_soln,
        "flow_direction": FlowDirection.forward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    organic_stream={
        "property_package": m.fs.prop_o,
        "flow_direction": FlowDirection.backward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    reaction_package=m.fs.reaxn,
    has_holdup=True,
)

# Define partition coefficients for each finite element in solex_rougher_load
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Al"] = 5.2 / 100
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Ca"] = 3.0 / 100
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Fe"] = (
#     24.7 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Sc"] = (
#     99.9 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Y"] = 99.9 / 100
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "La"] = (
#     32.4 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Ce"] = (
#     58.2 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Pr"] = (
#     58.2 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Nd"] = (
#     87.6 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Sm"] = (
#     99.9 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Gd"] = (
#     69.8 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[1, "aqueous", "organic", "Dy"] = (
#     96.6 / 100
# )

# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Al"] = 4.9 / 100
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Ca"] = (
#     12.3 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Fe"] = 6.4 / 100
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Sc"] = (
#     16.7 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Y"] = 99.9 / 100
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "La"] = (
#     23.2 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Ce"] = (
#     24.9 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Pr"] = (
#     15.1 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Nd"] = (
#     99.9 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Sm"] = (
#     99.9 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Gd"] = 7.6 / 100
# m.fs.solex_rougher_load.partition_coefficient[2, "aqueous", "organic", "Dy"] = 5.0 / 100

# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Al"] = 4.9 / 100
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Ca"] = (
#     12.3 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Fe"] = 6.4 / 100
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Sc"] = (
#     16.7 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Y"] = 99.9 / 100
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "La"] = (
#     23.2 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Ce"] = (
#     24.9 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Pr"] = (
#     15.1 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Nd"] = (
#     99.9 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Sm"] = (
#     99.9 / 100
# )
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Gd"] = 7.6 / 100
# m.fs.solex_rougher_load.partition_coefficient[3, "aqueous", "organic", "Dy"] = 5.0 / 100

# Dilute HCl feed
m.fs.acid_feed1 = Feed(property_package=m.fs.leach_soln)

m.fs.solex_rougher_scrub = SolventExtraction(
    number_of_finite_elements=1,
    dynamic=False,
    aqueous_stream={
        "property_package": m.fs.leach_soln,
        "flow_direction": FlowDirection.backward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    organic_stream={
        "property_package": m.fs.prop_o,
        "flow_direction": FlowDirection.forward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    reaction_package=m.fs.reaxn,
    has_holdup=True,
)

# Define partition coefficients for each finite element in solex_rougher_scrub
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Al"] = (
#     100 - 0.12
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Ca"] = (
#     100 - 0.55
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Fe"] = (
#     100 - 0.007
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Sc"] = (
#     100 - 99.9
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Y"] = (
#     100 - 99.9
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "La"] = (
#     100 - 99.8
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Ce"] = (
#     100 - 99.9
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Pr"] = (
#     100 - 99.9
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Nd"] = (
#     100 - 99.9
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Sm"] = (
#     100 - 99.9
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Gd"] = (
#     100 - 99.9
# ) / 100
# m.fs.solex_rougher_scrub.partition_coefficient[1, "aqueous", "organic", "Dy"] = (
#     100 - 99.9
# ) / 100

m.fs.acid_feed2 = Feed(property_package=m.fs.leach_soln)

m.fs.solex_rougher_strip = SolventExtraction(
    number_of_finite_elements=2,
    dynamic=False,
    aqueous_stream={
        "property_package": m.fs.leach_soln,
        "flow_direction": FlowDirection.backward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    organic_stream={
        "property_package": m.fs.prop_o,
        "flow_direction": FlowDirection.forward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    reaction_package=m.fs.reaxn,
    has_holdup=True,
)

# Define partition coefficients for each finite element in solex_rougher_strip
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Al"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Ca"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Fe"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Sc"] = (
#     100 - 98.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Y"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "La"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Ce"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Pr"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Nd"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Sm"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Gd"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_rougher_strip.partition_coefficient[:, "aqueous", "organic", "Dy"] = (
#     100 - 0.5
# ) / 100

# Separator for organic stream
m.fs.rougher_sep = Separator(
    property_package=m.fs.prop_o,
    outlet_list=["recycle", "purge"],
    split_basis=SplittingType.totalFlow,
    material_balance_type=MaterialBalanceType.componentTotal,
    momentum_balance_type=MomentumBalanceType.none,
    energy_split_basis=EnergySplittingType.none,
)
m.fs.rougher_mixer = Mixer(
    property_package=m.fs.prop_o,
    num_inlets=2,
    inlet_list=["make_up", "recycle"],
    material_balance_type=MaterialBalanceType.componentTotal,
    energy_mixing_type=MixingType.none,
    momentum_mixing_type=MomentumMixingType.none,
)

# Separators for aqueous streams
m.fs.load_sep = Separator(
    property_package=m.fs.leach_soln,
    outlet_list=["recycle", "purge"],
    split_basis=SplittingType.totalFlow,
    material_balance_type=MaterialBalanceType.componentTotal,
    momentum_balance_type=MomentumBalanceType.none,
    energy_split_basis=EnergySplittingType.none,
)
m.fs.scrub_sep = Separator(
    property_package=m.fs.leach_soln,
    outlet_list=["recycle", "purge"],
    split_basis=SplittingType.totalFlow,
    material_balance_type=MaterialBalanceType.componentTotal,
    momentum_balance_type=MomentumBalanceType.none,
    energy_split_basis=EnergySplittingType.none,
)

m.fs.sc_circuit_purge = Product(property_package=m.fs.prop_o)

m.fs.solex_cleaner_load = SolventExtraction(
    number_of_finite_elements=3,
    dynamic=False,
    aqueous_stream={
        "property_package": m.fs.leach_soln,
        "flow_direction": FlowDirection.forward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    organic_stream={
        "property_package": m.fs.prop_o,
        "flow_direction": FlowDirection.backward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    reaction_package=m.fs.reaxn,
    has_holdup=True,
)

# Define partition coefficients for each finite element in solex_cleaner_load
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Al"] = 3.6 / 100
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Ca"] = 3.7 / 100
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Fe"] = 2.1 / 100
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Sc"] = (
#     99.9 / 100
# )
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Y"] = 99.9 / 100
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "La"] = (
#     75.2 / 100
# )
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Ce"] = (
#     95.7 / 100
# )
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Pr"] = (
#     96.5 / 100
# )
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Nd"] = (
#     99.2 / 100
# )
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Sm"] = (
#     99.9 / 100
# )
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Gd"] = (
#     98.6 / 100
# )
# m.fs.solex_cleaner_load.partition_coefficient[:, "aqueous", "organic", "Dy"] = (
#     99.9 / 100
# )

m.fs.solex_cleaner_strip = SolventExtraction(
    number_of_finite_elements=3,
    dynamic=False,
    aqueous_stream={
        "property_package": m.fs.leach_soln,
        "flow_direction": FlowDirection.backward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    organic_stream={
        "property_package": m.fs.prop_o,
        "flow_direction": FlowDirection.forward,
        "has_energy_balance": False,
        "has_pressure_balance": False,
    },
    reaction_package=m.fs.reaxn,
    has_holdup=True,
)
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Al"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Ca"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Fe"] = (
#     100 - 5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Sc"] = (
#     100 - 98.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Y"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "La"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Ce"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Pr"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Nd"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Sm"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Gd"] = (
#     100 - 0.5
# ) / 100
# m.fs.solex_cleaner_strip.partition_coefficient[:, "aqueous", "organic", "Dy"] = (
#     100 - 0.5
# ) / 100

m.fs.cleaner_org_make_up = Feed(property_package=m.fs.prop_o)

# Separator and mixer for organic stream
m.fs.cleaner_sep = Separator(
    property_package=m.fs.prop_o,
    outlet_list=["recycle", "purge"],
    split_basis=SplittingType.totalFlow,
    material_balance_type=MaterialBalanceType.componentTotal,
    momentum_balance_type=MomentumBalanceType.none,
    energy_split_basis=EnergySplittingType.none,
)
m.fs.cleaner_mixer = Mixer(
    property_package=m.fs.prop_o,
    num_inlets=2,
    inlet_list=["make_up", "recycle"],
    material_balance_type=MaterialBalanceType.componentTotal,
    energy_mixing_type=MixingType.none,
    momentum_mixing_type=MomentumMixingType.none,
)

m.fs.leach_sx_mixer = Mixer(
    property_package=m.fs.leach_soln,
    num_inlets=2,
    inlet_list=["leach", "cleaner"],
    material_balance_type=MaterialBalanceType.componentTotal,
    energy_mixing_type=MixingType.none,
    momentum_mixing_type=MomentumMixingType.none,
)

m.fs.acid_feed3 = Feed(property_package=m.fs.leach_soln)
m.fs.cleaner_purge = Product(property_package=m.fs.prop_o)

# %% [markdown]
# ### Step 2.3 Create variables for the precipitation section
# Specify the necessary unit, property, and reaction models for the precipitation section.

# %%
# Precipitation property packages
m.fs.properties_aq = AqueousParameter()
m.fs.properties_solid = PrecipitateParameters()

# Precipitation unit model
m.fs.precipitator = Precipitator(
    property_package_aqueous=m.fs.properties_aq,
    property_package_precipitate=m.fs.properties_solid,
)

# Solid-liquid separator used to approximate a filter press
m.fs.sl_sep2 = SLSeparator(
    solid_property_package=m.fs.properties_solid,
    liquid_property_package=m.fs.leach_soln,
    material_balance_type=MaterialBalanceType.componentTotal,
    momentum_balance_type=MomentumBalanceType.none,
    energy_split_basis=EnergySplittingType.none,
)

m.fs.precip_sep = Separator(
    property_package=m.fs.leach_soln,
    outlet_list=["recycle", "purge"],
    split_basis=SplittingType.totalFlow,
    material_balance_type=MaterialBalanceType.componentTotal,
    momentum_balance_type=MomentumBalanceType.none,
    energy_split_basis=EnergySplittingType.none,
)

m.fs.precip_sx_mixer = Mixer(
    property_package=m.fs.leach_soln,
    num_inlets=2,
    inlet_list=["precip", "rougher"],
    material_balance_type=MaterialBalanceType.componentTotal,
    energy_mixing_type=MixingType.none,
    momentum_mixing_type=MomentumMixingType.none,
)

# Define outlets from the flowsheet
m.fs.precip_purge = Product(property_package=m.fs.properties_aq)

# %% [markdown]
# ### Step 2.3 Create variables for the product roaster section
# Specify the necessary unit, property, and reaction models for the roaster section.

# %%
# Define the relevant gas species
gas_species = {"O2", "H2O", "CO2", "N2"}

# Roaster property packages
m.fs.prop_gas = GenericParameterBlock(
    **get_prop(gas_species, ["Vap"], EosType.IDEAL),
    doc="gas property",
)
m.fs.prop_solid = PrecipitateParameters()

# Roaster unit model
m.fs.roaster = REEOxalateRoaster(
    property_package_gas=m.fs.prop_gas,
    property_package_precipitate_solid=m.fs.prop_solid,
    property_package_precipitate_liquid=m.fs.properties_aq,
    has_holdup=False,
    has_heat_transfer=True,
    has_pressure_change=True,
)

# %% [markdown]
# ### Step 2.3 Create translator block for property package changes
# Create a translator block for the properties package between units differing in property packages

# %%
m.fs.translator_leaching_to_precipitate = TranslatorLeachPrecip(
            inlet_property_package=m.fs.leach_soln,
            outlet_property_package=m.fs.properties_aq,
        )
m.fs.translator_precipitate_to_leaching = TranslatorLeachPrecip(
            inlet_property_package=m.fs.properties_aq,
            outlet_property_package=m.fs.leach_soln,
        )
m.fs.translator_sep_to_roast = TranslatorLeachPrecip(
            inlet_property_package=m.fs.leach_soln,
            outlet_property_package=m.fs.properties_aq,
        )
m.fs.translator_precip_sep_to_purge = TranslatorLeachPrecip(
            inlet_property_package=m.fs.leach_soln,
            outlet_property_package=m.fs.properties_aq,
        )

# %% [markdown]
# ### Step 2.4 Connect the unit models
# Next, use Pyomo arcs as streams to connect the units as portrayed in the flowsheet image above.

# %%
m.fs.leaching_sol_feed = Arc(
    source=m.fs.leach_solid_feed.outlet, destination=m.fs.leach.solid_inlet
)
m.fs.leaching_liq_feed = Arc(
    source=m.fs.leach_liquid_feed.outlet, destination=m.fs.leach_mixer.feed
)
m.fs.leaching_feed_mixture = Arc(
    source=m.fs.leach_mixer.outlet, destination=m.fs.leach.liquid_inlet
)
m.fs.leaching_solid_outlet = Arc(
    source=m.fs.leach.solid_outlet, destination=m.fs.sl_sep1.solid_inlet
)
m.fs.leaching_liquid_outlet = Arc(
    source=m.fs.leach.liquid_outlet, destination=m.fs.sl_sep1.liquid_inlet
)
m.fs.sl_sep1_solid_outlet = Arc(
    source=m.fs.sl_sep1.solid_outlet, destination=m.fs.leach_filter_cake.inlet
)
m.fs.sl_sep1_retained_liquid_outlet = Arc(
    source=m.fs.sl_sep1.retained_liquid_outlet,
    destination=m.fs.leach_filter_cake_liquid.inlet,
)
m.fs.sl_sep1_liquid_outlet = Arc(
    source=m.fs.sl_sep1.recovered_liquid_outlet,
    destination=m.fs.leach_sx_mixer.leach,
)
m.fs.sx_rougher_load_aq_feed = Arc(
    source=m.fs.leach_sx_mixer.outlet,
    destination=m.fs.solex_rougher_load.aqueous_inlet,
)
m.fs.sx_rougher_org_feed = Arc(
    source=m.fs.rougher_org_make_up.outlet, destination=m.fs.rougher_mixer.make_up
)
m.fs.sx_rougher_mixed_org_recycle = Arc(
    source=m.fs.rougher_mixer.outlet,
    destination=m.fs.solex_rougher_load.organic_inlet,
)
m.fs.sx_rougher_load_aq_outlet = Arc(
    source=m.fs.solex_rougher_load.aqueous_outlet,
    destination=m.fs.load_sep.inlet,
)
m.fs.sx_rougher_load_aq_recycle = Arc(
    source=m.fs.load_sep.recycle, destination=m.fs.leach_mixer.load_recycle
)
m.fs.sx_rougher_load_org_outlet = Arc(
    source=m.fs.solex_rougher_load.organic_outlet,
    destination=m.fs.solex_rougher_scrub.organic_inlet,
)
m.fs.sx_rougher_scrub_acid_feed = Arc(
    source=m.fs.acid_feed1.outlet,
    destination=m.fs.solex_rougher_scrub.aqueous_inlet,
)
m.fs.sx_rougher_scrub_aq_outlet = Arc(
    source=m.fs.solex_rougher_scrub.aqueous_outlet,
    destination=m.fs.scrub_sep.inlet,
)
m.fs.sx_rougher_scrub_aq_recycle = Arc(
    source=m.fs.scrub_sep.recycle, destination=m.fs.leach_mixer.scrub_recycle
)
m.fs.sx_rougher_scrub_org_outlet = Arc(
    source=m.fs.solex_rougher_scrub.organic_outlet,
    destination=m.fs.solex_rougher_strip.organic_inlet,
)
m.fs.sx_rougher_strip_acid_feed = Arc(
    source=m.fs.acid_feed2.outlet,
    destination=m.fs.solex_rougher_strip.aqueous_inlet,
)
m.fs.sx_rougher_strip_org_outlet = Arc(
    source=m.fs.solex_rougher_strip.organic_outlet,
    destination=m.fs.rougher_sep.inlet,
)
m.fs.sx_rougher_strip_org_purge = Arc(
    source=m.fs.rougher_sep.purge, destination=m.fs.sc_circuit_purge.inlet
)
m.fs.sx_rougher_strip_org_recycle = Arc(
    source=m.fs.rougher_sep.recycle, destination=m.fs.rougher_mixer.recycle
)
m.fs.sx_rougher_strip_aq_outlet = Arc(
    source=m.fs.solex_rougher_strip.aqueous_outlet,
    destination=m.fs.precip_sx_mixer.rougher,
)
m.fs.sx_cleaner_load_aq_feed = Arc(
    source=m.fs.precip_sx_mixer.outlet,
    destination=m.fs.solex_cleaner_load.aqueous_inlet,
)
m.fs.sx_cleaner_org_feed = Arc(
    source=m.fs.cleaner_org_make_up.outlet, destination=m.fs.cleaner_mixer.make_up
)
m.fs.sx_cleaner_mixed_org_recycle = Arc(
    source=m.fs.cleaner_mixer.outlet,
    destination=m.fs.solex_cleaner_load.organic_inlet,
)
m.fs.sx_cleaner_load_aq_outlet = Arc(
    source=m.fs.solex_cleaner_load.aqueous_outlet,
    destination=m.fs.leach_sx_mixer.cleaner,
)
m.fs.sx_cleaner_strip_acid_feed = Arc(
    source=m.fs.acid_feed3.outlet,
    destination=m.fs.solex_cleaner_strip.aqueous_inlet,
)
m.fs.sx_cleaner_load_org_outlet = Arc(
    source=m.fs.solex_cleaner_load.organic_outlet,
    destination=m.fs.solex_cleaner_strip.organic_inlet,
)
m.fs.sx_cleaner_strip_org_outlet = Arc(
    source=m.fs.solex_cleaner_strip.organic_outlet,
    destination=m.fs.cleaner_sep.inlet,
)
m.fs.sx_cleaner_strip_org_purge = Arc(
    source=m.fs.cleaner_sep.purge, destination=m.fs.cleaner_purge.inlet
)
m.fs.sx_cleaner_strip_org_recycle = Arc(
    source=m.fs.cleaner_sep.recycle, destination=m.fs.cleaner_mixer.recycle
)
# m.fs.sx_cleaner_strip_aq_outlet = Arc(
#     source=m.fs.solex_cleaner_strip.aqueous_outlet,
#     destination=m.fs.precipitator.aqueous_inlet,
# )
m.fs.sx_cleaner_strip_aq_outlet = Arc(
    source=m.fs.solex_cleaner_strip.aqueous_outlet,
    destination=m.fs.translator_leaching_to_precipitate.inlet,
)
m.fs.precip_aq_inlet = Arc(
    source=m.fs.translator_leaching_to_precipitate.outlet,
    destination=m.fs.precipitator.aqueous_inlet,
)
m.fs.precip_solid_outlet = Arc(
    source=m.fs.precipitator.precipitate_outlet,
    destination=m.fs.sl_sep2.solid_inlet,
)
# m.fs.precip_aq_outlet = Arc(
#     source=m.fs.precipitator.aqueous_outlet, destination=m.fs.sl_sep2.liquid_inlet
# )
m.fs.precip_aq_outlet = Arc(
    source=m.fs.precipitator.aqueous_outlet, destination=m.fs.translator_precipitate_to_leaching.inlet
)
m.fs.sl_sep2_solid_inlet = Arc(
    source=m.fs.translator_precipitate_to_leaching.outlet, destination=m.fs.sl_sep2.liquid_inlet
)
m.fs.sl_sep2_solid_outlet = Arc(
    source=m.fs.sl_sep2.solid_outlet, destination=m.fs.roaster.solid_inlet
)
m.fs.sl_sep2_liquid_outlet = Arc(
    source=m.fs.sl_sep2.recovered_liquid_outlet, destination=m.fs.precip_sep.inlet
)

# Check

# m.fs.sl_sep2_retained_liquid_outlet = Arc(
#     source=m.fs.sl_sep2.retained_liquid_outlet,
#     destination=m.fs.roaster.liquid_inlet,
# )

# Check 

m.fs.sl_sep2_retained_liquid_outlet = Arc(
    source=m.fs.sl_sep2.retained_liquid_outlet,
    destination=m.fs.translator_sep_to_roast.inlet,
)
m.fs.roaster_liquid_inlet = Arc(
    source=m.fs.translator_sep_to_roast.outlet,
    destination=m.fs.roaster.liquid_inlet,
)

# Check 

# m.fs.sl_sep2_aq_purge = Arc(
#     source=m.fs.precip_sep.purge, destination=m.fs.precip_purge.inlet
# )
m.fs.sl_sep2_aq_purge = Arc(
    source=m.fs.precip_sep.purge, destination=m.fs.translator_precip_sep_to_purge.inlet
)
m.fs.precip_purge_inlet = Arc(
    source=m.fs.translator_precip_sep_to_purge.outlet, destination=m.fs.precip_purge.inlet
)
m.fs.sl_sep2_aq_recycle = Arc(
    source=m.fs.precip_sep.recycle,
    destination=m.fs.precip_sx_mixer.precip,
)

TransformationFactory("network.expand_arcs").apply_to(m)

# %% [markdown]
# ### Step 2.5 Apply scaling
# In order for the flowsheet to solve, variables will need to be scaled appropriately. While variables often have a default scaling set, it is important to re-scale those with poor initial scaling in this flowsheet as there are many trace components resulting in variables with very small magnitudes.

# %%
def set_scaling(m):
    m.scaling_factor = Suffix(direction=Suffix.EXPORT)

    sb = ScalerBase()

    for var in m.fs.component_data_objects(Var, descend_into=True):
        if "temperature" in var.name:
            sb.set_variable_scaling_factor(var, 1e-2)
        if "pressure" in var.name:
            sb.set_variable_scaling_factor(var, 1e-5)
        if "flow_mol" in var.name: 
            sb.set_variable_scaling_factor(var, 1e-3)
    return m

# %% [markdown]
# ### Step 2.6 Set the operating conditions

# %% [markdown]
# Now specify the inlet feed conditions into the flowsheet and fix any necessary unit model variables such that the
# degrees of freedom of the system are equal to zero.

# %%
eps = 1e-7 * units.mg / units.L
dehpa_conc = 975.8e3 * units.mg / units.L
kerosene_conc = 8.2e5 * units.mg / units.L
Temp_room = 303 * units.K 
P_atm = 101235 * units.Pa

m.fs.leach_liquid_feed.flow_vol.fix(224.3 * units.L / units.hour)
m.fs.leach_liquid_feed.conc_mass_comp.fix(1e-10 * units.mg / units.L)
m.fs.leach_liquid_feed.conc_mass_comp[0, "H"].fix(2 * 0.05 * 1e3 * units.mg / units.L)
m.fs.leach_liquid_feed.conc_mass_comp[0, "HSO4"].fix(1e-8 * units.mg / units.L)
m.fs.leach_liquid_feed.conc_mass_comp[0, "SO4"].fix(0.05 * 96e3 * units.mg / units.L)
m.fs.leach_liquid_feed.properties[0.0].pressure.fix(P_atm)
m.fs.leach_liquid_feed.properties[0.0].temperature.fix(Temp_room)

m.fs.leach_solid_feed.flow_mass.fix(22.68 * units.kg / units.hour)
m.fs.leach_solid_feed.mass_frac_comp[0, "inerts"].fix(0.6952 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Al2O3"].fix(0.237 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Fe2O3"].fix(0.0642 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "CaO"].fix(3.31e-3 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Sc2O3"].fix(2.77966e-05 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Y2O3"].fix(3.28653e-05 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "La2O3"].fix(6.77769e-05 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Ce2O3"].fix(0.000156161 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Pr2O3"].fix(1.71438e-05 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Nd2O3"].fix(6.76618e-05 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Sm2O3"].fix(1.47926e-05 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Gd2O3"].fix(1.0405e-05 * units.kg / units.kg)
m.fs.leach_solid_feed.mass_frac_comp[0, "Dy2O3"].fix(7.54827e-06 * units.kg / units.kg)

m.fs.leach.volume.fix(100 * units.gallon)

m.fs.leach.mscontactor.liquid[0.0,2].temperature.fix(Temp_room)
m.fs.leach.mscontactor.liquid[0.0,2].pressure.fix(P_atm)

m.fs.leach_mixer.mixed_state[0.0].pressure.fix(P_atm)
m.fs.leach_mixer.mixed_state[0.0].temperature.fix(Temp_room)
# m.fs.leach_mixer.load_recycle_state[0.0].temperature.fix(Temp_room)
# m.fs.leach_mixer.scrub_recycle_state[0.0].pressure.fix(P_atm)
# m.fs.leach_mixer.scrub_recycle_state[0.0].temperature.fix(Temp_room)
# m.fs.leach_mixer.load_recycle_state[0.0].pressure.fix(P_atm)
m.fs.load_sep.recycle_state[0.0].pressure.fix(P_atm)
m.fs.load_sep.recycle_state[0.0].temperature.fix(Temp_room)
m.fs.scrub_sep.recycle_state[0.0].pressure.fix(P_atm)
m.fs.scrub_sep.recycle_state[0.0].temperature.fix(Temp_room)

# m.fs.leach_filter_cake_liquid.properties[0.0].pressure.fix(P_atm)
# m.fs.leach_filter_cake_liquid.properties[0.0].temperature.fix(Temp_room)

# m.fs.leach_sx_mixer.leach_state[0.0].pressure.fix(P_atm)
# m.fs.leach_sx_mixer.leach_state[0.0].temperature.fix(Temp_room)
m.fs.leach_sx_mixer.mixed_state[0.0].pressure.fix(P_atm)
m.fs.leach_sx_mixer.mixed_state[0.0].temperature.fix(Temp_room)

m.fs.load_sep.split_fraction[:, "recycle"].fix(0.9)
m.fs.scrub_sep.split_fraction[:, "recycle"].fix(0.9)

m.fs.solex_rougher_load.mscontactor.volume[:].fix(0.4 * units.m**3)
m.fs.solex_rougher_load.mscontactor.volume_frac_stream[:, :, "aqueous"].fix(0.5)
m.fs.solex_rougher_load.area_cross_stage[:] = 1
m.fs.solex_rougher_load.elevation[:] = 0
m.fs.solex_rougher_load.mscontactor.aqueous[0.0,3].temperature.fix(Temp_room)
# m.fs.solex_rougher_load.mscontactor.aqueous[0.0,3].pressure.fix(P_atm)
m.fs.solex_rougher_load.mscontactor.organic[0.0,1].temperature.fix(Temp_room)

m.fs.solex_rougher_scrub.mscontactor.volume[:].fix(0.4 * units.m**3)
m.fs.solex_rougher_scrub.mscontactor.volume_frac_stream[:, :, "aqueous"].fix(0.5)
m.fs.solex_rougher_scrub.area_cross_stage[:] = 1
m.fs.solex_rougher_scrub.elevation[:] = 0
m.fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].temperature.fix(Temp_room)
m.fs.solex_rougher_scrub.mscontactor.organic[0.0,1].temperature.fix(Temp_room)

m.fs.solex_rougher_strip.mscontactor.volume[:].fix(0.4 * units.m**3)
m.fs.solex_rougher_strip.mscontactor.volume_frac_stream[:, :, "aqueous"].fix(0.5)
m.fs.solex_rougher_strip.area_cross_stage[:] = 1
m.fs.solex_rougher_strip.elevation[:] = 0
m.fs.solex_rougher_strip.mscontactor.organic[0.0,2].temperature.fix(Temp_room)
m.fs.solex_rougher_strip.mscontactor.aqueous[0.0,1].temperature.fix(Temp_room)

m.fs.solex_cleaner_load.mscontactor.volume[:].fix(0.4 * units.m**3)
m.fs.solex_cleaner_load.mscontactor.volume_frac_stream[:, :, "aqueous"].fix(0.5)
m.fs.solex_cleaner_load.area_cross_stage[:] = 1
m.fs.solex_cleaner_load.elevation[:] = 0
m.fs.solex_cleaner_load.mscontactor.aqueous[0.0,3].temperature.fix(Temp_room)
m.fs.solex_cleaner_load.mscontactor.organic[0.0,1].temperature.fix(Temp_room)

m.fs.solex_cleaner_strip.mscontactor.volume[:].fix(0.4 * units.m**3)
m.fs.solex_cleaner_strip.mscontactor.volume_frac_stream[:, :, "aqueous"].fix(0.5)
m.fs.solex_cleaner_strip.area_cross_stage[:] = 1
m.fs.solex_cleaner_strip.elevation[:] = 0
m.fs.solex_cleaner_strip.mscontactor.organic[0.0,3].temperature.fix(Temp_room)
# m.fs.solex_cleaner_strip.mscontactor.organic[0.0,3].pressure.fix(P_atm)
m.fs.solex_cleaner_strip.mscontactor.aqueous[0.0,1].temperature.fix(Temp_room)

# Note: This stream + m.fs.s09 = 62.01 L/hr
m.fs.rougher_org_make_up.flow_vol.fix(6.201)

m.fs.rougher_org_make_up.conc_mass_comp[0, "Al_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Ca_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Fe_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Sc_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Y_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "La_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Ce_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Pr_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Nd_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Sm_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Gd_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Dy_o"].fix(eps)
m.fs.rougher_org_make_up.conc_mass_comp[0, "DEHPA"].fix(dehpa_conc)
m.fs.rougher_org_make_up.conc_mass_comp[0, "Kerosene"].fix(kerosene_conc)
m.fs.rougher_org_make_up.properties[0.0].pressure.fix(P_atm)
m.fs.rougher_org_make_up.properties[0.0].temperature.fix(Temp_room)

m.fs.rougher_mixer.mixed_state[0.0].pressure.fix(P_atm)
m.fs.rougher_mixer.mixed_state[0.0].temperature.fix(Temp_room)

m.fs.acid_feed1.flow_vol.fix(0.09)
m.fs.acid_feed1.conc_mass_comp[0, "H2O"].fix(1000000)
m.fs.acid_feed1.conc_mass_comp[0, "H"].fix(10.36)
m.fs.acid_feed1.conc_mass_comp[0, "SO4"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "HSO4"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Cl"].fix(359.64)
m.fs.acid_feed1.conc_mass_comp[0, "Al"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Ca"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Fe"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Sc"].fix(1000)
m.fs.acid_feed1.conc_mass_comp[0, "Y"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "La"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Ce"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Pr"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Nd"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Sm"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Gd"].fix(eps)
m.fs.acid_feed1.conc_mass_comp[0, "Dy"].fix(eps)
m.fs.acid_feed1.properties[0.0].pressure.fix(P_atm)
m.fs.acid_feed1.properties[0.0].temperature.fix(Temp_room)

# TODO: flow rate and HCl concentration are not defined in REESim
m.fs.acid_feed2.flow_vol.fix(0.09)
m.fs.acid_feed2.conc_mass_comp[0, "H2O"].fix(1000000)
m.fs.acid_feed2.conc_mass_comp[0, "H"].fix(
    10.36 * 4
)  # Arbitrarily choose 4x the dilute solution
m.fs.acid_feed2.conc_mass_comp[0, "SO4"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "HSO4"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Cl"].fix(359.64 * 4)
m.fs.acid_feed2.conc_mass_comp[0, "Al"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Ca"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Fe"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Sc"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Y"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "La"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Ce"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Pr"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Nd"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Sm"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Gd"].fix(eps)
m.fs.acid_feed2.conc_mass_comp[0, "Dy"].fix(eps)
m.fs.acid_feed2.properties[0.0].pressure.fix(P_atm)
m.fs.acid_feed2.properties[0.0].temperature.fix(Temp_room)

m.fs.rougher_sep.split_fraction[:, "recycle"].fix(0.9)
m.fs.rougher_sep.purge_state[0.0].pressure.fix(P_atm)
m.fs.rougher_sep.purge_state[0.0].temperature.fix(Temp_room)
m.fs.rougher_sep.recycle_state[0.0].pressure.fix(P_atm)
m.fs.rougher_sep.recycle_state[0.0].temperature.fix(Temp_room)


# TODO: flow rate and HCl concentration are not defined in REESim
m.fs.acid_feed3.flow_vol.fix(9)
m.fs.acid_feed3.conc_mass_comp[0, "H2O"].fix(1000000)
m.fs.acid_feed3.conc_mass_comp[0, "H"].fix(
    10.36 * 4
)  # Arbitrarily choose 4x the dilute solution
m.fs.acid_feed3.conc_mass_comp[0, "SO4"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "HSO4"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Cl"].fix(359.64 * 4)
m.fs.acid_feed3.conc_mass_comp[0, "Al"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Ca"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Fe"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Sc"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Y"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "La"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Ce"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Pr"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Nd"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Sm"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Gd"].fix(eps)
m.fs.acid_feed3.conc_mass_comp[0, "Dy"].fix(eps)
m.fs.acid_feed3.properties[0.0].pressure.fix(P_atm)
m.fs.acid_feed3.properties[0.0].temperature.fix(Temp_room)

# Note: This stream + m.fs.s18 = 62.01 L/hr
m.fs.cleaner_org_make_up.flow_vol.fix(6.201)

m.fs.cleaner_org_make_up.conc_mass_comp[0, "Al_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Ca_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Fe_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Sc_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Y_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "La_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Ce_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Pr_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Nd_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Sm_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Gd_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Dy_o"].fix(eps)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "DEHPA"].fix(dehpa_conc)
m.fs.cleaner_org_make_up.conc_mass_comp[0, "Kerosene"].fix(kerosene_conc)
m.fs.cleaner_org_make_up.properties[0.0].pressure.fix(P_atm)
m.fs.cleaner_org_make_up.properties[0.0].temperature.fix(Temp_room)

# m.fs.cleaner_mixer.make_up_state[0.0].temperature.fix(Temp_room)
m.fs.cleaner_mixer.mixed_state[0.0].pressure.fix(P_atm)
m.fs.cleaner_mixer.mixed_state[0.0].temperature.fix(Temp_room)
#check
# m.fs.cleaner_mixer.recycle_state[0.0].pressure.fix(P_atm)
# m.fs.cleaner_mixer.recycle_state[0.0].temperature.fix(Temp_room)

m.fs.cleaner_sep.split_fraction[:, "recycle"].fix(0.9)
m.fs.cleaner_sep.purge_state[0.0].pressure.fix(P_atm)
m.fs.cleaner_sep.purge_state[0.0].temperature.fix(Temp_room)
m.fs.cleaner_sep.recycle_state[0.0].pressure.fix(P_atm)
m.fs.cleaner_sep.recycle_state[0.0].temperature.fix(Temp_room)

m.fs.sl_sep1.liquid_recovery.fix(0.7)
m.fs.sl_sep1.split.recovered_state[0.0].pressure.fix(P_atm)
m.fs.sl_sep1.split.recovered_state[0.0].temperature.fix(Temp_room)
m.fs.sl_sep1.split.retained_state[0.0].pressure.fix(P_atm)
m.fs.sl_sep1.split.retained_state[0.0].temperature.fix(Temp_room)
m.fs.sl_sep2.liquid_recovery.fix(0.88)
# m.fs.sl_sep2.liquid_inlet_state[0.0].pressure.fix(P_atm)
# m.fs.sl_sep2.liquid_inlet_state[0.0].temperature.fix(Temp_room)
m.fs.sl_sep2.split.recovered_state[0.0].pressure.fix(P_atm)
m.fs.sl_sep2.split.recovered_state[0.0].temperature.fix(Temp_room)
m.fs.sl_sep2.split.retained_state[0.0].pressure.fix(P_atm)
m.fs.sl_sep2.split.retained_state[0.0].temperature.fix(Temp_room)

m.fs.translator_precipitate_to_leaching.outlet.pressure.fix(P_atm)
m.fs.translator_precipitate_to_leaching.outlet.temperature.fix(Temp_room)

m.fs.precipitator.cv_precipitate[0].temperature.fix(348.15 * units.K)

m.fs.precip_sep.split_fraction[:, "recycle"].fix(0.9)
m.fs.precip_sep.purge_state[0.0].pressure.fix(P_atm)
m.fs.precip_sep.purge_state[0.0].temperature.fix(Temp_room)
m.fs.precip_sep.recycle_state[0.0].pressure.fix(P_atm)
m.fs.precip_sep.recycle_state[0.0].temperature.fix(Temp_room)

m.fs.precip_sx_mixer.mixed_state[0.0].pressure.fix(P_atm)
m.fs.precip_sx_mixer.mixed_state[0.0].temperature.fix(Temp_room)

# Roaster gas feed
m.fs.roaster.deltaP.fix(0)
m.fs.roaster.gas_inlet.temperature.fix(1330)
m.fs.roaster.gas_inlet.pressure.fix(101325)
# Inlet flue gas mole flow rate
fgas = 0.00781
# Inlet flue gas composition, typical flue gas by burning CH4 with air with stoichiometric ratio of 2.3
gas_comp = {
    "O2": 0.1118,
    "H2O": 0.1005,
    "CO2": 0.0431,
    "N2": 0.7446,
}
for i, v in gas_comp.items():
    m.fs.roaster.gas_inlet.mole_frac_comp[0, i].fix(v)
m.fs.roaster.gas_inlet.flow_mol.fix(fgas)

# Fix outlet product temperature
m.fs.roaster.gas_outlet.temperature.fix(873.15)

# Fix operating conditions
m.fs.roaster.frac_comp_recovery.fix(0.95)

# %%
print(dof(m))
# Out:
# 0

# %% [markdown]
# # Step 3: Solve the square problem
# ## Step 3.1: Initialize the system
# Since there are multiple recycle loops involved, sequential decomposition will be used to initialize the flowsheet and tear sets must be specified to successfully initialize the system.

# %%
def initialize_system(m):
    # Initialize the model with sequential decomposition
    seq = SequentialDecomposition()
    seq.options.tear_method = "Direct"
    seq.options.iterLim = 1
    # Identify recycle streams
    seq.options.tear_set = [
        m.fs.leaching_feed_mixture,
        m.fs.sx_rougher_load_aq_feed,
        m.fs.sx_rougher_mixed_org_recycle,
        m.fs.sx_cleaner_load_aq_feed,
        m.fs.sx_cleaner_mixed_org_recycle,
    ]

    # Print initialization order for user visibility
    G = seq.create_graph(m)
    order = seq.calculation_order(G)
    print("Initialization Order")
    for o in order:
        print(o[0].name)

    # Supply tear guesses with initial values that are close to the solution
    tear_guesses1 = {
        "flow_vol": {0: 747.99},
        "conc_mass_comp": {
            (0, "Al"): 180.84,
            (0, "Ca"): 28.93,
            (0, "Ce"): 5.48,
            (0, "Dy"): 4.46e-11,
            (0, "Fe"): 269.98,
            (0, "Gd"): 2.60e-7,
            (0, "H"): 20.06,
            (0, "H2O"): 1000000,
            (0, "HSO4"): 963.06,
            (0, "Cl"): 1e-8,
            (0, "La"): 0.0037,
            (0, "Nd"): 1.81e-7,
            (0, "Pr"): 3.65e-6,
            (0, "SO4"): 486.24,
            (0, "Sc"): 4.17e-11,
            (0, "Sm"): 6.30e-10,
            (0, "Y"): 7.18e-11,
        },
    }

    # tear_guesses1 = {
    #     "flow_vol": {0: 606.7964},
    #     "conc_mass_comp": {
    #         (0, "Al"): 153.821,
    #         (0, "Ca"): 68.314,
    #         (0, "Ce"): 13.215,
    #         (0, "Dy"): 4.322,
    #         (0, "Fe"): 71.489,
    #         (0, "Gd"): 7.884,
    #         (0, "H"): 49.115,
    #         (0, "H2O"): 1000000,
    #         (0, "HSO4"): 2405.095,
    #         (0, "Cl"): 0.0102,
    #         (0, "La"): 13.339,
    #         (0, "Nd"): 10.432,
    #         (0, "Pr"): 10.658,
    #         (0, "SO4"): 2415.109,
    #         (0, "Sc"): 0.00095,
    #         (0, "Sm"): 9.035,
    #         (0, "Y"): 6.9546,
    #     },
    # }

    tear_guesses2 = {
        "flow_vol": {0: 62.01},
        "conc_mass_comp": {
            (0, "Al_o"): 1e-9,
            (0, "Ca_o"): 1e-9,
            (0, "Ce_o"): 1e-4,
            (0, "Dy_o"): 1e-7,
            (0, "Fe_o"): 1e-7,
            (0, "Gd_o"): 1e-6,
            (0, "La_o"): 1e-5,
            (0, "Nd_o"): 1e-4,
            (0, "Pr_o"): 1e-6,
            (0, "Sc_o"): 250,
            (0, "Sm_o"): 1e-6,
            (0, "Y_o"): 1e-6,
            (0, "DEHPA"): 975.8e3,
            (0, "Kerosene"): 820e3,
        },
    }

    # tear_guesses2 = {
    #     "flow_vol": {0: 62.01},
    #     "conc_mass_comp": {
    #         (0, "Al_o"): 0.0142,
    #         (0, "Ca_o"): 0.01419,
    #         (0, "Ce_o"): 0.01409,
    #         (0, "Dy_o"): 0.01406,
    #         (0, "Fe_o"): 0.01417,
    #         (0, "Gd_o"): 0.01407,
    #         (0, "La_o"): 0.01409,
    #         (0, "Nd_o"): 0.01408,
    #         (0, "Pr_o"): 0.01408,
    #         (0, "Sc_o"): 0.01418,
    #         (0, "Sm_o"): 0.01408,
    #         (0, "Y_o"): 0.01414,
    #         (0, "DEHPA"): 975.8e3,
    #         (0, "Kerosene"): 820e3,
    #     },
    # }

    tear_guesses3 = {
        "flow_vol": {0: 520},
        "conc_mass_comp": {
            (0, "Al"): 430,
            (0, "Ca"): 99,
            (0, "Ce"): 2,
            (0, "Dy"): 0.01,
            (0, "Fe"): 660,
            (0, "Gd"): 0.1,
            (0, "H"): 2,
            (0, "H2O"): 1000000,
            (0, "HSO4"): 900,
            (0, "Cl"): 0.1,
            (0, "La"): 1,
            (0, "Nd"): 1,
            (0, "Pr"): 0.1,
            (0, "SO4"): 4000,
            (0, "Sc"): 0.05,
            (0, "Sm"): 0.07,
            (0, "Y"): 0.1,
        },
    }

    # tear_guesses3 = {
    #     "flow_vol": {0: 424.906},
    #     "conc_mass_comp": {
    #         (0, "Al"): 244.075,
    #         (0, "Ca"): 108.397,
    #         (0, "Ce"): 20.970,
    #         (0, "Dy"): 6.857,
    #         (0, "Fe"): 113.435,
    #         (0, "Gd"): 12.511,
    #         (0, "H"): 33.849,
    #         (0, "H2O"): 1000000,
    #         (0, "HSO4"): 2402.895,
    #         (0, "Cl"): 0.0122,
    #         (0, "La"): 21.166,
    #         (0, "Nd"): 16.554,
    #         (0, "Pr"): 16.912,
    #         (0, "SO4"): 2415.6109,
    #         (0, "Sc"): 0.0015,
    #         (0, "Sm"): 14.337,
    #         (0, "Y"): 11.035,
    #     },
    # }

    tear_guesses4 = {
        "flow_vol": {0: 64},
        "conc_mass_comp": {
            (0, "Al_o"): 1e-9,
            (0, "Ca_o"): 1e-9,
            (0, "Ce_o"): 1e-5,
            (0, "Dy_o"): 1e-7,
            (0, "Fe_o"): 1e-7,
            (0, "Gd_o"): 1e-6,
            (0, "La_o"): 1e-5,
            (0, "Nd_o"): 1e-5,
            (0, "Pr_o"): 1e-6,
            (0, "Sc_o"): 321.34,
            (0, "Sm_o"): 1e-6,
            (0, "Y_o"): 1e-6,
            (0, "DEHPA"): 975.8e3,
            (0, "Kerosene"): 820e3,
        },
    }

    # tear_guesses4 = {
    #     "flow_vol": {0: 62.01},
    #     "conc_mass_comp": {
    #         (0, "Al_o"): 0.0142,
    #         (0, "Ca_o"): 0.01419,
    #         (0, "Ce_o"): 0.01409,
    #         (0, "Dy_o"): 0.01406,
    #         (0, "Fe_o"): 0.01417,
    #         (0, "Gd_o"): 0.01407,
    #         (0, "La_o"): 0.01409,
    #         (0, "Nd_o"): 0.01408,
    #         (0, "Pr_o"): 0.01408,
    #         (0, "Sc_o"): 0.01418,
    #         (0, "Sm_o"): 0.01408,
    #         (0, "Y_o"): 0.01414,
    #         (0, "DEHPA"): 975.8e3,
    #         (0, "Kerosene"): 820e3,
    #     },
    # }

    tear_guesses5 = {
        "flow_vol": {0: 5.7},
        "conc_mass_comp": {
            (0, "Al"): 5,
            (0, "Ca"): 16,
            (0, "Ce"): 346,
            (0, "Dy"): 6,
            (0, "Fe"): 1,
            (0, "Gd"): 22,
            (0, "H"): 14,
            (0, "H2O"): 1000000,
            (0, "HSO4"): 1e-7,
            (0, "Cl"): 1400,
            (0, "La"): 160,
            (0, "Nd"): 121,
            (0, "Pr"): 30,
            (0, "SO4"): 1e-7,
            (0, "Sc"): 149.2,
            (0, "Sm"): 13,
            (0, "Y"): 18,
        },
    }

    # tear_guesses5 = {
    #     "flow_vol": {0: 0.09},
    #     "conc_mass_comp": {
    #         (0, "Al"): 8.73e-6,
    #         (0, "Ca"): 1.3487e-5,
    #         (0, "Ce"): 4.13e-5,
    #         (0, "Dy"): 4.742e-5,
    #         (0, "Fe"): 1.852e-5,
    #         (0, "Gd"): 4.576e-5,
    #         (0, "H"): 41.380,
    #         (0, "H2O"): 1000000,
    #         (0, "HSO4"): 2.611e-5,
    #         (0, "Cl"): 9.372,
    #         (0, "La"): 4.108e-5,
    #         (0, "Nd"): 4.244e-5,
    #         (0, "Pr"): 4.17e-5,
    #         (0, "SO4"): 7.597e-6,
    #         (0, "Sc"): 2.618e-5,
    #         (0, "Sm"): 4.409e-5,
    #         (0, "Y"): 2.8912e-5,
    #     },
    # }

    # Pass the tear guesses to the sequential decomposition tool
    seq.set_guesses_for(m.fs.leach.liquid_inlet, tear_guesses1)
    seq.set_guesses_for(m.fs.solex_rougher_load.organic_inlet, tear_guesses2)
    seq.set_guesses_for(m.fs.solex_rougher_load.aqueous_inlet, tear_guesses3)
    seq.set_guesses_for(m.fs.solex_cleaner_load.organic_inlet, tear_guesses4)
    seq.set_guesses_for(m.fs.solex_cleaner_load.aqueous_inlet, tear_guesses5)

    # Associate units with specialized initializers
    initializer_feed = FeedInitializer()
    feed_units = [
        m.fs.leach_liquid_feed,
        m.fs.leach_solid_feed,
        m.fs.rougher_org_make_up,
        m.fs.acid_feed1,
        m.fs.acid_feed2,
        m.fs.acid_feed3,
        m.fs.cleaner_org_make_up,
    ]

    initializer_product = ProductInitializer()
    product_units = [
        m.fs.leach_filter_cake,
        m.fs.leach_filter_cake_liquid,
        m.fs.cleaner_purge,
        m.fs.sc_circuit_purge,
        m.fs.precip_purge,
    ]

    initializer_sep = SeparatorInitializer()
    sep_units = [
        m.fs.scrub_sep,
        m.fs.precip_sep,
        m.fs.cleaner_sep,
        m.fs.rougher_sep,
    ]

    initializer_mix = MixerInitializer()
    mix_units = [
        m.fs.precip_sx_mixer,
        m.fs.cleaner_mixer,
        m.fs.rougher_mixer,
    ]

    initializer_leach = LeachingTrainInitializer()
    leach_units = [
        m.fs.leach,
    ]

    initializer_sx = SolventExtractionInitializer()
    sx_units = [
        m.fs.solex_rougher_load,
        m.fs.solex_rougher_scrub,
        m.fs.solex_rougher_strip,
        m.fs.solex_cleaner_load,
        m.fs.solex_cleaner_strip,
    ]

    # The BT Initializer will be used for any units not handled by the above initializers
    initializer_bt = BlockTriangularizationInitializer()

    # Initialize units using their respective initializers
    # For units that cannot be initialized with the initializers, the unit is manually fixed, solved, and then unfixed
    def function(unit):
        if unit in feed_units:
            _log.info(f"Initializing {unit}")
            initializer_feed.initialize(unit)
        elif unit in product_units:
            _log.info(f"Initializing {unit}")
            initializer_product.initialize(unit)
        elif unit in sep_units:
            _log.info(f"Initializing {unit}")
            initializer_sep.initialize(unit)
        elif unit in mix_units:
            _log.info(f"Initializing {unit}")
            initializer_mix.initialize(unit)
        elif unit in leach_units:
            _log.info(f"Initializing {unit}")
            initializer_leach.initialize(unit)
        elif unit in sx_units:
            _log.info(f"Initializing {unit}")
            initializer_sx.initialize(unit)
        else:
            _log.info(f"Initializing {unit}")
            initializer_bt.initialize(unit)

    seq.run(m, function)

# %% [markdown]
# ## Step 3.2: Add solver
# Solve the model by running the flowsheet using the ipopt solver.

# %%
def solve(m):
    solver = SolverFactory("ipopt")
    results = solver.solve(m, tee=True)

# %% [markdown]
# ## Step 3.3 Solve the system
# Scale, initialize, and solve the model.

# %%
# Applies scaling to the model after the models are constructed and operating conditions are set
set_scaling(m)
scaling = TransformationFactory("core.scale_model")
scaled_model = scaling.create_using(m, rename=False)

# Initializes the scaled model
initialize_system(scaled_model)

# Solves the scaled model
solve(scaled_model)
# solve(m)
# Out:
# Initialization Order
# fs.leach_solid_feed
# fs.leach
# fs.sl_sep1
# fs.leach_mixer
# fs.sc_circuit_purge
# fs.sl_sep2
# fs.precip_sep
# fs.translator_precip_sep_to_purge
# fs.precip_purge
# 2025-05-11 20:52:30 [INFO] idaes.__main__: Initializing fs.leach_solid_feed
# 2025-05-11 20:52:30 [INFO] idaes.__main__: Initializing fs.leach_liquid_feed
# 2025-05-11 20:52:32 [INFO] idaes.__main__: Initializing fs.solex_rougher_load
# 2025-05-11 20:52:33 [INFO] idaes.init.fs.solex_rougher_load.mscontactor: Stream Initialization Completed.
# 2025-05-11 20:52:34 [INFO] idaes.init.fs.solex_rougher_load.mscontactor: Initialization Completed, optimal - <undefined>
# Initializing element 1
# Ipopt 3.13.2: linear_solver=ma57
# max_iter=200
# nlp_scaling_method=gradient-based
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      207
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       10
#
# Total number of variables............................:       68
#                      variables with only lower bounds:       29
#                 variables with lower and upper bounds:        2
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       68
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.18e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (2180)
#    1  0.0000000e+00 4.81e+03 7.20e+00  -1.0 8.87e+02    -  9.92e-01 4.12e-01h  1
#    2  0.0000000e+00 4.74e+03 1.79e+03  -1.0 5.32e+02    -  1.00e+00 1.49e-02h  1
#    3  0.0000000e+00 4.74e+03 1.17e+07  -1.0 5.24e+02    -  1.00e+00 1.55e-04h  1
#    4r 0.0000000e+00 4.74e+03 1.00e+03   2.4 0.00e+00    -  0.00e+00 3.11e-07R  6
#    5r 0.0000000e+00 3.39e+03 9.66e+04   2.4 3.28e+04    -  4.11e-01 1.57e-02f  1
#    6r 0.0000000e+00 3.17e+03 5.94e+04   2.4 2.08e+02    -  1.00e+00 3.02e-02f  1
#    7r 0.0000000e+00 6.10e+02 1.17e+04   1.7 2.39e+01    -  8.76e-01 8.06e-01f  1
#    8r 0.0000000e+00 1.29e+02 3.46e+03   1.0 5.21e+00    -  1.00e+00 7.89e-01f  1
#    9r 0.0000000e+00 2.76e+01 3.98e+03   0.3 8.47e+00    -  9.45e-01 7.85e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 3.75e-02 2.65e+03   0.3 3.42e+00    -  7.02e-01 1.00e+00f  1
#   11r 0.0000000e+00 2.91e-02 9.01e+00   0.3 1.01e+00    -  1.00e+00 1.00e+00f  1
#   12r 0.0000000e+00 6.11e-03 8.87e+02  -1.8 2.91e+00    -  9.31e-01 7.94e-01f  1
#   13r 0.0000000e+00 3.18e-03 5.70e+03  -1.8 1.79e+00    -  6.73e-01 5.02e-01f  1
#   14r 0.0000000e+00 1.20e-03 9.48e+03  -1.8 6.12e-01    -  8.56e-01 6.53e-01f  1
#   15r 0.0000000e+00 2.86e-04 3.75e+03  -1.8 1.69e-01    -  1.00e+00 9.03e-01f  1
#   16r 0.0000000e+00 1.85e-04 8.13e-01  -1.8 3.12e-02    -  1.00e+00 1.00e+00f  1
#   17r 0.0000000e+00 4.48e-05 5.98e+03  -2.7 1.75e-01    -  9.99e-01 7.61e-01f  1
#   18r 0.0000000e+00 2.90e-04 5.96e+00  -2.7 4.68e-01    -  1.00e+00 1.00e+00f  1
#   19r 0.0000000e+00 3.12e-05 3.30e+00  -2.7 1.54e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 0.0000000e+00 9.39e-06 1.89e-02  -2.7 1.02e-02    -  1.00e+00 1.00e+00h  1
#   21r 0.0000000e+00 6.67e-05 2.34e+03  -4.0 3.00e-01    -  8.42e-01 7.47e-01f  1
#   22r 0.0000000e+00 1.37e-02 1.06e+03  -4.0 3.67e+00    -  9.09e-01 8.76e-01f  1
#   23r 0.0000000e+00 2.99e-04 2.37e+01  -4.0 4.91e-01    -  1.00e+00 1.00e+00f  1
#   24r 0.0000000e+00 4.39e-06 5.38e-03  -4.0 3.03e-03    -  1.00e+00 1.00e+00h  1
#   25r 0.0000000e+00 9.08e-06 1.36e+03  -6.0 1.03e-01    -  9.87e-01 8.08e-01f  1
#   26r 0.0000000e+00 7.63e-01 4.41e+02  -6.0 3.55e+01    -  8.97e-01 6.72e-01f  1
#   27r 0.0000000e+00 1.68e-02 2.62e+00  -6.0 2.94e+00    -  1.00e+00 1.00e+00h  1
#   28r 0.0000000e+00 1.29e-02 4.61e-02  -6.0 3.23e+00    -  1.00e+00 1.00e+00h  1
#   29r 0.0000000e+00 8.73e-04 1.77e-03  -6.0 8.55e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30r 0.0000000e+00 5.44e-06 1.13e-05  -6.0 6.74e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 30
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   3.2534201407643506e-07    5.4386663919103739e-06
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.2534201407643506e-07    5.4386663919103739e-06
#
#
# Number of objective function evaluations             = 37
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 37
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 32
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 30
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.043
# Total CPU secs in NLP function evaluations           =      0.002
#
# EXIT: Optimal Solution Found.
# Initializing element 2
# Ipopt 3.13.2: linear_solver=ma57
# max_iter=200
# nlp_scaling_method=gradient-based
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      207
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       10
#
# Total number of variables............................:       68
#                      variables with only lower bounds:       29
#                 variables with lower and upper bounds:        2
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       68
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.18e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (2180)
#    1  0.0000000e+00 4.81e+03 7.20e+00  -1.0 8.87e+02    -  9.92e-01 4.12e-01h  1
#    2  0.0000000e+00 4.74e+03 1.79e+03  -1.0 5.32e+02    -  1.00e+00 1.49e-02h  1
#    3  0.0000000e+00 4.74e+03 1.17e+07  -1.0 5.24e+02    -  1.00e+00 1.55e-04h  1
#    4r 0.0000000e+00 4.74e+03 1.00e+03   2.4 0.00e+00    -  0.00e+00 3.88e-07R  3
#    5r 0.0000000e+00 3.39e+03 9.67e+04   2.4 3.28e+04    -  4.12e-01 1.57e-02f  1
#    6r 0.0000000e+00 3.17e+03 5.94e+04   2.4 2.07e+02    -  1.00e+00 3.03e-02f  1
#    7r 0.0000000e+00 6.11e+02 1.17e+04   1.7 2.38e+01    -  8.76e-01 8.06e-01f  1
#    8r 0.0000000e+00 1.29e+02 3.47e+03   1.0 5.26e+00    -  1.00e+00 7.88e-01f  1
#    9r 0.0000000e+00 2.80e+01 4.04e+03   0.3 8.44e+00    -  9.45e-01 7.83e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 3.67e-02 2.67e+03   0.3 3.40e+00    -  7.00e-01 1.00e+00f  1
#   11r 0.0000000e+00 2.91e-02 9.23e+00   0.3 1.03e+00    -  1.00e+00 1.00e+00f  1
#   12r 0.0000000e+00 6.12e-03 8.91e+02  -1.8 2.90e+00    -  9.31e-01 7.93e-01f  1
#   13r 0.0000000e+00 3.23e-03 5.86e+03  -1.8 1.88e+00    -  6.72e-01 4.96e-01f  1
#   14r 0.0000000e+00 1.23e-03 9.27e+03  -1.8 6.24e-01    -  8.54e-01 6.56e-01f  1
#   15r 0.0000000e+00 3.14e-04 3.93e+03  -1.8 1.77e-01    -  1.00e+00 8.99e-01f  1
#   16r 0.0000000e+00 2.08e-04 1.83e-01  -1.8 5.21e-02    -  1.00e+00 1.00e+00f  1
#   17r 0.0000000e+00 6.83e-05 6.70e+03  -4.0 1.55e-01    -  8.96e-01 6.61e-01f  1
#   18r 0.0000000e+00 6.63e-03 3.02e+03  -4.0 2.74e+00    -  8.75e-01 8.13e-01f  1
#   19r 0.0000000e+00 5.10e-03 9.64e+03  -4.0 2.26e+00    -  8.46e-01 6.15e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 0.0000000e+00 1.40e-03 1.85e+03  -4.0 9.15e-01    -  9.17e-01 8.97e-01f  1
#   21r 0.0000000e+00 1.16e-05 3.15e+00  -4.0 9.53e-02    -  1.00e+00 1.00e+00f  1
#   22r 0.0000000e+00 4.39e-06 7.16e-03  -4.0 7.06e-04    -  1.00e+00 1.00e+00h  1
#   23r 0.0000000e+00 4.39e-06 7.77e-06  -4.0 2.43e-05    -  1.00e+00 1.00e+00h  1
#   24r 0.0000000e+00 8.22e-06 1.78e+03  -6.0 9.81e-02    -  9.76e-01 8.07e-01f  1
#   25r 0.0000000e+00 7.60e-01 8.89e+02  -6.0 3.56e+01    -  8.96e-01 6.69e-01f  1
#   26r 0.0000000e+00 1.06e-02 9.15e+00  -6.0 2.17e+00    -  1.00e+00 1.00e+00h  1
#   27r 0.0000000e+00 9.16e-03 3.14e-02  -6.0 2.72e+00    -  1.00e+00 1.00e+00h  1
#   28r 0.0000000e+00 4.70e-04 9.94e-04  -6.0 6.26e-01    -  1.00e+00 1.00e+00h  1
#   29r 0.0000000e+00 1.56e-06 3.36e-06  -6.0 3.61e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 29
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   9.3644075663608752e-08    1.5615408983649104e-06
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   9.3644075663608752e-08    1.5615408983649104e-06
#
#
# Number of objective function evaluations             = 33
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 33
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 31
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 29
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.030
# Total CPU secs in NLP function evaluations           =      0.003
#
# EXIT: Optimal Solution Found.
# Initializing element 3
# Ipopt 3.13.2: linear_solver=ma57
# max_iter=200
# nlp_scaling_method=gradient-based
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      207
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       10
#
# Total number of variables............................:       68
#                      variables with only lower bounds:       29
#                 variables with lower and upper bounds:        2
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       68
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.18e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (2180)
#    1  0.0000000e+00 4.72e+03 7.03e+00  -1.0 8.88e+02    -  9.92e-01 4.23e-01h  1
#    2  0.0000000e+00 4.64e+03 1.71e+03  -1.0 5.22e+02    -  1.00e+00 1.64e-02h  1
#    3  0.0000000e+00 4.64e+03 1.01e+07  -1.0 5.14e+02    -  1.00e+00 1.72e-04h  1
#    4r 0.0000000e+00 4.64e+03 1.00e+03   2.4 0.00e+00    -  0.00e+00 2.80e-07R  4
#    5r 0.0000000e+00 3.35e+03 1.02e+05   2.4 3.28e+04    -  4.45e-01 1.54e-02f  1
#    6r 0.0000000e+00 3.12e+03 6.35e+04   2.4 1.82e+02    -  1.00e+00 3.33e-02f  1
#    7r 0.0000000e+00 8.10e+02 1.61e+04   1.7 2.01e+01    -  9.89e-01 7.39e-01f  1
#    8r 0.0000000e+00 1.69e+02 4.17e+03   1.0 8.30e+00    -  1.00e+00 7.90e-01f  1
#    9r 0.0000000e+00 3.72e+01 4.55e+03   0.3 7.75e+00    -  9.66e-01 7.81e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 4.79e-02 2.96e+03   0.3 3.33e+00    -  6.34e-01 1.00e+00f  1
#   11r 0.0000000e+00 2.85e-02 1.40e+01   0.3 8.87e-01    -  1.00e+00 1.00e+00f  1
#   12r 0.0000000e+00 6.16e-03 9.17e+02  -1.8 2.70e+00    -  9.29e-01 7.89e-01f  1
#   13r 0.0000000e+00 3.40e-03 5.89e+03  -1.8 2.12e+00    -  6.56e-01 4.73e-01f  1
#   14r 0.0000000e+00 1.30e-03 7.92e+03  -1.8 6.00e-01    -  8.13e-01 6.52e-01f  1
#   15r 0.0000000e+00 3.51e-04 5.19e+03  -1.8 1.83e-01    -  1.00e+00 8.71e-01f  1
#   16r 0.0000000e+00 2.05e-04 2.82e-01  -1.8 6.28e-02    -  1.00e+00 1.00e+00f  1
#   17r 0.0000000e+00 7.23e-05 7.72e+03  -4.0 1.65e-01    -  8.88e-01 6.40e-01f  1
#   18r 0.0000000e+00 1.00e-02 3.46e+03  -4.0 3.12e+00    -  8.73e-01 8.08e-01f  1
#   19r 0.0000000e+00 7.90e-03 2.39e+03  -4.0 2.40e+00    -  7.37e-01 8.34e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 0.0000000e+00 3.49e-04 6.94e+03  -4.0 4.82e-01    -  9.19e-01 1.00e+00f  1
#   21r 0.0000000e+00 4.46e-06 2.88e+00  -4.0 4.36e-02    -  1.00e+00 1.00e+00h  1
#   22r 0.0000000e+00 4.46e-06 6.50e-02  -4.0 5.72e-03    -  1.00e+00 1.00e+00h  1
#   23r 0.0000000e+00 4.46e-06 2.62e-04  -4.0 2.00e-04    -  1.00e+00 1.00e+00h  1
#   24r 0.0000000e+00 1.08e-05 1.57e+03  -6.0 1.03e-01    -  9.54e-01 8.07e-01f  1
#   25r 0.0000000e+00 5.58e-01 1.44e+03  -6.0 3.82e+01    -  8.92e-01 4.92e-01f  1
#   26r 0.0000000e+00 1.66e-03 1.86e+01  -6.0 5.08e-01    -  1.00e+00 1.00e+00h  1
#   27r 0.0000000e+00 2.51e-03 1.23e+00  -6.0 1.31e+00    -  1.00e+00 1.00e+00h  1
#   28r 0.0000000e+00 1.19e-05 1.07e-03  -6.0 9.28e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 28
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   8.4932593290422049e-07    1.1928192520826997e-05
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   8.4932593290422049e-07    1.1928192520826997e-05
#
#
# Number of objective function evaluations             = 33
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 33
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 30
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 28
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.029
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
# 2025-05-11 20:52:35 [INFO] idaes.__main__: Initializing fs.rougher_org_make_up
# 2025-05-11 20:52:35 [INFO] idaes.__main__: Initializing fs.acid_feed1
# 2025-05-11 20:52:35 [INFO] idaes.__main__: Initializing fs.acid_feed2
# 2025-05-11 20:52:35 [INFO] idaes.__main__: Initializing fs.solex_cleaner_load
# WARNING (W1002): Setting Var
# 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,1].conc_mol_comp[SO4]' to a
# numeric value `0.0` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,1].conc_mass_comp[SO4]' to a
# numeric value `-2.2737367544323206e-13` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,2].conc_mol_comp[SO4]' to a
# numeric value `0.0` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,2].conc_mass_comp[SO4]' to a
# numeric value `0.0` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,3].conc_mol_comp[SO4]' to a
# numeric value `0.0` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,3].conc_mass_comp[SO4]' to a
# numeric value `0.0` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# 2025-05-11 20:52:36 [INFO] idaes.init.fs.solex_cleaner_load.mscontactor: Stream Initialization Completed.
# 2025-05-11 20:52:36 [INFO] idaes.init.fs.solex_cleaner_load.mscontactor: Initialization Completed, optimal - <undefined>
# Initializing element 1
# Ipopt 3.13.2: linear_solver=ma57
# max_iter=200
# nlp_scaling_method=gradient-based
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      207
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       10
#
# Total number of variables............................:       68
#                      variables with only lower bounds:       29
#                 variables with lower and upper bounds:        2
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       68
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.18e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (2180)
#    1  0.0000000e+00 2.17e+03 3.20e+00  -1.0 9.07e+02    -  9.92e-01 7.35e-01h  1
#    2  0.0000000e+00 1.88e+03 9.33e+02  -1.0 2.40e+02    -  1.00e+00 1.33e-01h  1
#    3  0.0000000e+00 1.87e+03 6.50e+05  -1.0 2.08e+02    -  1.00e+00 1.95e-03h  1
#    4  0.0000000e+00 1.87e+03 3.25e+10  -1.0 2.08e+02    -  1.00e+00 1.98e-05h  1
#    5r 0.0000000e+00 1.87e+03 1.00e+03   2.0 0.00e+00    -  0.00e+00 9.79e-08R  2
#    6r 0.0000000e+00 1.67e+03 4.43e+03   2.0 3.34e+04    -  9.85e-02 6.16e-03f  1
#    7r 0.0000000e+00 1.47e+03 1.67e+04   1.3 1.22e+02    -  8.50e-01 1.72e-02f  1
#    8r 0.0000000e+00 1.05e+03 1.91e+04   1.3 6.62e+00    -  1.00e+00 2.49e-01f  1
#    9r 0.0000000e+00 2.22e-01 2.15e+02   1.3 1.12e+00    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 1.60e-01 4.17e+02  -0.1 1.19e+00    -  1.00e+00 8.47e-01f  1
#   11r 0.0000000e+00 1.96e-01 1.26e+03  -0.1 1.47e+00    -  1.00e+00 8.95e-01f  1
#   12r 0.0000000e+00 1.89e-01 2.57e+01  -0.1 1.32e+00    -  1.00e+00 1.00e+00f  1
#   13r 0.0000000e+00 4.18e-02 2.98e+03  -1.5 3.86e-02    -  1.00e+00 7.88e-01f  1
#   14r 0.0000000e+00 7.46e-03 4.47e+03  -1.5 8.19e-02    -  9.92e-01 8.25e-01f  1
#   15r 0.0000000e+00 4.84e-04 2.17e+00  -1.5 7.08e-02    -  1.00e+00 1.00e+00f  1
#   16r 0.0000000e+00 4.25e-04 1.59e+03  -2.2 6.32e-02    -  1.00e+00 8.95e-01f  1
#   17r 0.0000000e+00 2.60e-05 2.75e+00  -2.2 1.54e-02    -  1.00e+00 1.00e+00f  1
#   18r 0.0000000e+00 1.05e-05 9.63e-02  -2.2 2.74e-03    -  1.00e+00 1.00e+00h  1
#   19r 0.0000000e+00 4.00e-06 5.55e+02  -3.3 6.69e-03    -  9.81e-01 8.63e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 0.0000000e+00 1.13e-06 3.40e-01  -3.3 3.11e-03    -  1.00e+00 1.00e+00f  1
#   21r 0.0000000e+00 7.82e-07 1.25e-02  -3.3 2.43e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 21
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   7.8192878127361947e-07    7.8192878127361947e-07
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   7.8192878127361947e-07    7.8192878127361947e-07
#
#
# Number of objective function evaluations             = 24
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 24
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 23
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 21
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.032
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# Initializing element 2
# Ipopt 3.13.2: linear_solver=ma57
# max_iter=200
# nlp_scaling_method=gradient-based
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      207
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       10
#
# Total number of variables............................:       68
#                      variables with only lower bounds:       29
#                 variables with lower and upper bounds:        2
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       68
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.18e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (2180)
#    1  0.0000000e+00 2.19e+03 3.23e+00  -1.0 9.08e+02    -  9.92e-01 7.32e-01h  1
#    2  0.0000000e+00 1.92e+03 9.43e+02  -1.0 2.44e+02    -  1.00e+00 1.27e-01h  1
#    3  0.0000000e+00 1.91e+03 6.89e+05  -1.0 2.13e+02    -  1.00e+00 1.82e-03h  1
#    4  0.0000000e+00 1.91e+03 2.78e+10  -1.0 2.12e+02    -  1.00e+00 2.46e-05h  1
#    5r 0.0000000e+00 1.91e+03 1.00e+03   2.0 0.00e+00    -  0.00e+00 9.17e-08R  2
#    6r 0.0000000e+00 1.70e+03 4.22e+03   2.0 3.34e+04    -  9.42e-02 6.29e-03f  1
#    7r 0.0000000e+00 1.50e+03 1.71e+04   1.3 1.32e+02    -  9.02e-01 1.61e-02f  1
#    8r 0.0000000e+00 1.04e+03 1.82e+04   1.3 5.97e+00    -  1.00e+00 2.77e-01f  1
#    9r 0.0000000e+00 2.26e-01 1.55e+02   1.3 1.13e+00    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 1.72e-01 4.88e+02  -0.8 1.13e+00    -  9.93e-01 8.29e-01f  1
#   11r 0.0000000e+00 2.37e-01 3.87e+03  -0.8 1.88e+00    -  1.00e+00 6.24e-01f  1
#   12r 0.0000000e+00 1.04e-01 1.30e+03  -0.8 7.48e-01    -  9.19e-01 8.40e-01f  1
#   13r 0.0000000e+00 6.48e-02 2.47e+01  -0.8 6.46e-01    -  1.00e+00 1.00e+00f  1
#   14r 0.0000000e+00 8.41e-03 1.88e+03  -1.5 9.30e-02    -  1.00e+00 8.71e-01f  1
#   15r 0.0000000e+00 5.83e-05 3.29e-02  -1.5 1.87e-03    -  1.00e+00 1.00e+00f  1
#   16r 0.0000000e+00 2.32e-04 1.44e+03  -5.0 4.92e-02    -  9.53e-01 8.04e-01f  1
#   17r 0.0000000e+00 1.13e-04 3.60e+03  -5.0 2.37e-02    -  7.92e-01 6.66e-01f  1
#   18r 0.0000000e+00 4.09e-05 1.55e+03  -5.0 4.97e-03    -  6.84e-01 6.51e-01f  1
#   19r 0.0000000e+00 9.12e-06 1.59e+03  -5.0 2.79e-03    -  7.10e-01 7.95e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 0.0000000e+00 2.35e-06 4.18e+02  -5.0 6.90e-04    -  8.87e-01 7.47e-01f  1
#   21r 0.0000000e+00 3.77e-07 1.93e+02  -5.0 6.36e-05    -  9.77e-01 8.40e-01f  1
#
# Number of Iterations....: 21
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   3.7658979712418272e-07    3.7658979712418272e-07
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.7658979712418272e-07    3.7658979712418272e-07
#
#
# Number of objective function evaluations             = 24
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 24
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 23
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 21
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.008
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# Initializing element 3
# Ipopt 3.13.2: linear_solver=ma57
# max_iter=200
# nlp_scaling_method=gradient-based
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      207
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       10
#
# Total number of variables............................:       68
#                      variables with only lower bounds:       29
#                 variables with lower and upper bounds:        2
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       68
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.18e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (2180)
#    1  0.0000000e+00 2.22e+03 3.25e+00  -1.0 9.08e+02    -  9.92e-01 7.28e-01h  1
#    2  0.0000000e+00 1.95e+03 9.52e+02  -1.0 2.47e+02    -  1.00e+00 1.22e-01h  1
#    3  0.0000000e+00 1.95e+03 7.27e+05  -1.0 2.17e+02    -  1.00e+00 1.72e-03h  1
#    4  0.0000000e+00 1.95e+03 2.95e+10  -1.0 2.16e+02    -  1.00e+00 2.45e-05h  1
#    5r 0.0000000e+00 1.95e+03 1.00e+03   2.0 0.00e+00    -  0.00e+00 8.65e-08R  2
#    6r 0.0000000e+00 1.72e+03 4.09e+03   2.0 3.34e+04    -  9.14e-02 6.41e-03f  1
#    7r 0.0000000e+00 1.53e+03 1.81e+04   1.3 1.41e+02    -  9.79e-01 1.54e-02f  1
#    8r 0.0000000e+00 1.04e+03 1.71e+04   1.3 5.20e+00    -  1.00e+00 3.15e-01f  1
#    9r 0.0000000e+00 2.29e-01 1.09e+02   1.3 1.12e+00    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 0.0000000e+00 1.66e-01 4.88e+02  -0.8 1.00e+00    -  9.97e-01 8.35e-01f  1
#   11r 0.0000000e+00 1.98e-01 1.49e+03  -0.8 1.48e+00    -  1.00e+00 6.97e-01f  1
#   12r 0.0000000e+00 1.28e-01 2.44e+03  -0.8 9.10e-01    -  1.00e+00 8.28e-01f  1
#   13r 0.0000000e+00 5.37e-02 2.56e+01  -0.8 4.90e-01    -  1.00e+00 1.00e+00f  1
#   14r 0.0000000e+00 6.20e-03 1.48e+03  -1.5 7.95e-02    -  1.00e+00 8.86e-01f  1
#   15r 0.0000000e+00 9.38e-05 3.93e-01  -1.5 1.68e-02    -  1.00e+00 1.00e+00f  1
#   16r 0.0000000e+00 1.00e-04 2.61e+03  -3.3 2.73e-02    -  9.63e-01 7.67e-01f  1
#   17r 0.0000000e+00 9.03e-05 3.34e+03  -3.3 2.53e-02    -  9.26e-01 7.67e-01f  1
#   18r 0.0000000e+00 5.08e-07 6.92e+02  -3.3 3.77e-04    -  9.66e-01 1.00e+00f  1
#
# Number of Iterations....: 18
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.0785207545120539e-07    5.0785207545120539e-07
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.0785207545120539e-07    5.0785207545120539e-07
#
#
# Number of objective function evaluations             = 21
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 21
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 20
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 18
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.030
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2025-05-11 20:52:38 [INFO] idaes.__main__: Initializing fs.cleaner_org_make_up
# 2025-05-11 20:52:38 [INFO] idaes.__main__: Initializing fs.acid_feed3
# 2025-05-11 20:52:38 [INFO] idaes.__main__: Initializing fs.leach
# 2025-05-11 20:52:39 [INFO] idaes.init.fs.leach.mscontactor: Stream Initialization Completed.
# 2025-05-11 20:52:39 [INFO] idaes.init.fs.leach.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-05-11 20:52:39 [INFO] idaes.__main__: Initializing fs.load_sep
# 2025-05-11 20:52:40 [INFO] idaes.__main__: Initializing fs.solex_rougher_scrub
# WARNING (W1002): Setting Var
# 'fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[SO4]' to a
# numeric value `0.0` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var
# 'fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[SO4]' to a
# numeric value `0.0` outside the bounds (1e-20, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# 2025-05-11 20:52:40 [INFO] idaes.init.fs.solex_rougher_scrub.mscontactor: Stream Initialization Completed.
# 2025-05-11 20:52:40 [INFO] idaes.init.fs.solex_rougher_scrub.mscontactor: Initialization Completed, optimal - <undefined>
# Initializing element 1
# Ipopt 3.13.2: linear_solver=ma57
# max_iter=200
# nlp_scaling_method=gradient-based
# tol=1e-06
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:      207
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       10
#
# Total number of variables............................:       68
#                      variables with only lower bounds:       29
#                 variables with lower and upper bounds:        2
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       68
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 7.33e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Reallocating memory for MA57: lfact (2180)
#    1  0.0000000e+00 2.00e+03 3.42e+00  -1.0 9.06e+02    -  9.93e-01 7.27e-01h  1
#    2  0.0000000e+00 1.81e+03 1.00e+03  -1.0 2.48e+02    -  1.00e+00 9.69e-02h  1
#    3  0.0000000e+00 1.81e+03 1.01e+06  -1.0 2.24e+02    -  1.00e+00 1.21e-03h  1
#    4  0.0000000e+00 1.80e+03 2.23e+08  -1.0 3.55e+02    -  1.00e+00 4.71e-03h  1
#    5  0.0000000e+00 1.44e+02 1.60e+08  -1.0 3.51e+02    -  1.00e+00 9.89e-01h  1
#    6  0.0000000e+00 1.36e+02 1.36e+13  -1.0 1.97e+02    -  7.38e-06 2.02e-01f  1
# Reallocating memory for MA57: lfact (2494)
#    7  0.0000000e+00 9.21e+01 9.19e+12  -1.0 1.50e+02    -  1.00e+00 3.23e-01h  1
#    8  0.0000000e+00 8.47e+01 7.06e+12  -1.0 2.31e+02    -  2.21e-01 2.32e-01h  1
#    9  0.0000000e+00 7.92e+01 6.60e+12  -1.0 1.22e+02    -  1.00e+00 6.62e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 7.71e+01 6.35e+12  -1.0 4.31e+02    -  4.44e-01 3.75e-02h  1
#   11  0.0000000e+00 7.71e+01 6.47e+12  -1.0 5.28e+02    -  1.00e+00 9.64e-04h  1
#   12r 0.0000000e+00 7.71e+01 1.00e+03   0.8 0.00e+00    -  0.00e+00 3.02e-07R  6
#   13r 0.0000000e+00 2.23e+01 2.12e+03   0.8 6.44e+03    -  3.59e-03 1.06e-03f  1
#   14r 0.0000000e+00 2.08e+01 6.52e+04   0.8 4.82e+01    -  2.12e-01 4.60e-03f  1
#   15r 0.0000000e+00 1.62e+01 3.04e+04   0.8 2.81e+00    -  9.93e-01 2.29e-01f  1
#   16r 0.0000000e+00 1.25e+01 2.30e+04   0.8 3.88e+00    -  2.34e-01 2.47e-01f  1
#   17r 0.0000000e+00 6.32e+00 1.48e+04   0.8 5.37e+00    -  1.00e+00 5.81e-01f  1
#   18r 0.0000000e+00 1.25e+00 4.99e+01   0.8 3.57e+00    -  1.00e+00 1.00e+00f  1
#   19r 0.0000000e+00 1.20e+00 2.45e+03  -1.3 1.04e+01    -  9.15e-01 7.09e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 0.0000000e+00 4.06e-01 6.49e+03  -1.3 9.64e-01    -  1.00e+00 6.87e-01f  1
#   21r 0.0000000e+00 1.03e-01 1.67e+03  -1.3 6.20e-01    -  7.57e-01 7.48e-01f  1
#   22r 0.0000000e+00 1.32e-02 4.18e+03  -1.3 1.38e-01    -  1.00e+00 8.71e-01f  1
#   23r 0.0000000e+00 2.50e-04 2.25e-01  -1.3 9.83e-02    -  1.00e+00 1.00e+00f  1
#   24r 0.0000000e+00 3.66e-03 4.18e+03  -2.9 7.44e-01    -  1.00e+00 6.59e-01f  1
#   25r 0.0000000e+00 5.17e-02 2.84e+03  -2.9 2.17e+00    -  5.52e-01 8.50e-01f  1
#   26r 0.0000000e+00 5.59e-03 1.93e+02  -2.9 2.16e-01    -  1.00e+00 9.08e-01f  1
#   27r 0.0000000e+00 3.14e-04 8.31e-01  -2.9 1.11e-02    -  1.00e+00 1.00e+00f  1
#   28r 0.0000000e+00 3.15e-04 5.54e-03  -2.9 6.32e-04    -  1.00e+00 1.00e+00h  1
#   29r 0.0000000e+00 3.28e-04 7.73e+02  -4.4 7.94e-02    -  9.84e-01 7.88e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30r 0.0000000e+00 2.76e-01 3.77e+02  -4.4 5.29e+00    -  9.43e-01 8.20e-01f  1
#   31r 0.0000000e+00 1.17e-02 1.31e+02  -4.4 1.24e+00    -  1.00e+00 1.00e+00h  1
#   32r 0.0000000e+00 3.19e-04 1.14e-01  -4.4 4.64e-03    -  1.00e+00 1.00e+00h  1
#   33r 0.0000000e+00 3.19e-04 6.95e-07  -4.4 5.99e-06    -  1.00e+00 1.00e+00h  1
#   34r 0.0000000e+00 3.19e-04 1.79e+02  -6.6 1.19e-02    -  9.84e-01 8.13e-01f  1
#   35r 0.0000000e+00 4.63e+00 1.11e+02  -6.6 1.88e+01    -  9.77e-01 9.61e-01f  1
#   36r 0.0000000e+00 6.32e-01 2.93e+01  -6.6 1.34e+01    -  1.00e+00 1.00e+00h  1
#   37r 0.0000000e+00 8.72e-03 2.03e-01  -6.6 5.01e-01    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 37
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   5.7564994958441405e-04    5.7564994958441405e-04
# Constraint violation....:   2.7960167104840216e-04    2.7960167104840216e-04
# Complementarity.........:   2.4823980489024643e-07    2.4823980489024643e-07
# Overall NLP error.......:   2.7960167104840216e-04    5.7564994958441405e-04
#
#
# Number of objective function evaluations             = 45
# Number of objective gradient evaluations             = 14
# Number of equality constraint evaluations            = 45
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 40
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 38
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.026
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.

# %%
dt=DiagnosticsToolbox(scaled_model)
dt.report_numerical_issues()
# Out:
# ====================================================================================
# Model Statistics
#
#     Jacobian Condition Number: 1.295E+27
#
# ------------------------------------------------------------------------------------
# 5 WARNINGS
#
#     WARNING: 44 Constraints with large residuals (>1.0E-05)
#     WARNING: 96 Variables at or outside bounds (tol=0.0E+00)
#     WARNING: 37 Variables with extreme Jacobian values (<1.0E-08 or >1.0E+08)
#     WARNING: 1 Constraint with extreme Jacobian values (<1.0E-08 or >1.0E+08)
#     WARNING: 412 pairs of constraints are parallel (to tolerance 1.0E-08)
#
# ------------------------------------------------------------------------------------
# 8 Cautions
#
#     Caution: 1904 Variables with value close to their bounds (abs=1.0E-04, rel=1.0E-04)
#     Caution: 1918 Variables with value close to zero (tol=1.0E-08)
#     Caution: 1401 Variables with extreme value (<1.0E-04 or >1.0E+04)
#     Caution: 34 Constraints with mismatched terms
#     Caution: 14 Constraints with potential cancellation of terms
#     Caution: 1480 Variables with extreme Jacobian values (<1.0E-04 or >1.0E+04)
#     Caution: 1491 Constraints with extreme Jacobian values (<1.0E-04 or >1.0E+04)
#     Caution: 4560 extreme Jacobian Entries (<1.0E-04 or >1.0E+04)
#
# ------------------------------------------------------------------------------------
# Suggested next steps:
#
#     display_constraints_with_large_residuals()
#     compute_infeasibility_explanation()
#     display_variables_at_or_outside_bounds()
#     display_variables_with_extreme_jacobians()
#     display_constraints_with_extreme_jacobians()
#     display_near_parallel_constraints()
#
# ====================================================================================

# %%
dt.display_constraints_with_large_residuals()
# Out:
# ====================================================================================
# The following constraint(s) have large residuals (>1.0E-05):
#
#     fs.leach.mscontactor.liquid[0.0,1].hso4_dissociation: 8.96459E-05
#     fs.leach.mscontactor.liquid[0.0,2].hso4_dissociation: 5.61041E-04
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,1].reaction_rate_eq[Fe2O3]: 1.84798E-03
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,1].reaction_rate_eq[CaO]: 3.53636E-03
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,1].reaction_rate_eq[Y2O3]: 3.67391E-05
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,1].reaction_rate_eq[La2O3]: 4.49855E-05
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,1].reaction_rate_eq[Ce2O3]: 4.34313E-05
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,1].reaction_rate_eq[Pr2O3]: 3.27449E-05
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,1].reaction_rate_eq[Nd2O3]: 1.89883E-05
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,1].reaction_rate_eq[Sm2O3]: 2.81361E-05
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,1].reaction_rate_eq[Dy2O3]: 1.24878E-05
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,2].reaction_rate_eq[Al2O3]: 9.47980E-02
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,2].reaction_rate_eq[Fe2O3]: 2.05303E-02
#     fs.leach.mscontactor.heterogeneous_reactions[0.0,2].reaction_rate_eq[CaO]: 3.09140E-03
#     fs.sl_sep1.split.sum_split_frac[0.0]: 3.00000E-01
#     fs.sl_sep1.split.recovered_state[0.0].hso4_dissociation: 5.98342E-04
#     fs.leach_mixer.mixed_state[0.0].hso4_dissociation: 9.81903E-04
#     fs.solex_rougher_load.mscontactor.aqueous[0.0,1].hso4_dissociation: 5.94518E-04
#     fs.solex_rougher_load.mscontactor.aqueous[0.0,2].hso4_dissociation: 5.94260E-04
#     fs.solex_rougher_load.mscontactor.aqueous[0.0,3].hso4_dissociation: 5.98382E-04
#     fs.solex_rougher_scrub.mscontactor.aqueous_inherent_reaction_constraint[0.0,1,liquid,Cl]: 2.88020E-04
#     fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reaction_constraint[0.0,1,liquid,Cl]: 2.88020E-04
#     fs.solex_rougher_scrub.mscontactor.aqueous_material_balance[0.0,1,Cl]: 2.88814E-04
#     fs.solex_rougher_strip.mscontactor.aqueous_inherent_reaction_constraint[0.0,2,liquid,Cl]: 1.18981E-03
#     fs.solex_rougher_strip.mscontactor.aqueous_heterogeneous_reaction_constraint[0.0,2,liquid,Cl]: 1.18981E-03
#     fs.solex_rougher_strip.mscontactor.aqueous_material_balance[0.0,2,Cl]: 1.24843E-03
#     fs.load_sep.recycle_state[0.0].hso4_dissociation: 5.98240E-04
#     fs.load_sep.purge_state[0.0].hso4_dissociation: 5.94005E-04
#     fs.solex_cleaner_strip.mscontactor.aqueous[0.0,1].pH_constraint[liquid]: 2.29032E-03
#     fs.leach_sx_mixer.mixed_state[0.0].hso4_dissociation: 5.98255E-04
#     fs.precipitator.vol_balance[0.0]: 1.65055E-04
#     fs.precipitator.aqueous_depletion[0.0,H2O]: 1.00000E-03
#     fs.roaster.energy_balance_eqn[0.0]: 1.24996E+02
#     fs.leaching_sol_feed_expanded.mass_frac_comp_equality[0.0,Y2O3]: 1.05912E-04
#     fs.leaching_sol_feed_expanded.mass_frac_comp_equality[0.0,La2O3]: 1.78038E-04
#     fs.leaching_sol_feed_expanded.mass_frac_comp_equality[0.0,Ce2O3]: 8.70688E-05
#     fs.leaching_sol_feed_expanded.mass_frac_comp_equality[0.0,Pr2O3]: 1.78856E-04
#     fs.leaching_sol_feed_expanded.mass_frac_comp_equality[0.0,Nd2O3]: 1.23545E-04
#     fs.leaching_sol_feed_expanded.mass_frac_comp_equality[0.0,Sm2O3]: 1.49846E-04
#     fs.leaching_sol_feed_expanded.mass_frac_comp_equality[0.0,Gd2O3]: 1.32396E-04
#     fs.leaching_sol_feed_expanded.mass_frac_comp_equality[0.0,Dy2O3]: 7.03939E-05
#     fs.sx_rougher_org_feed_expanded.flow_vol_equality[0.0]: 6.20100E+00
#     fs.sx_cleaner_org_feed_expanded.flow_vol_equality[0.0]: 6.20100E+00
#     fs.sx_cleaner_strip_acid_feed_expanded.flow_vol_equality[0.0]: 9.00000E+00
#
# ====================================================================================

# %%
scaled_model.fs.solex_cleaner_load.aqueous_inlet.conc_mass_comp.pprint()
scaled_model.fs.solex_cleaner_load.aqueous_inlet.flow_vol.pprint()
# Out:
# IndexedVar : Size=17, Index=fs._time*fs.leach_soln.component_list, ReferenceTo=fs.solex_cleaner_load.mscontactor.aqueous_inlet_state[:].component('conc_mass_comp')[...]
#     Key           : Lower : Value                  : Upper : Fixed : Stale : Domain
#       (0.0, 'Al') : 1e-20 :  8.737419928839822e-06 :  None : False : False :  Reals
#       (0.0, 'Ca') : 1e-20 : 1.3487504994543125e-05 :  None : False : False :  Reals
#       (0.0, 'Ce') : 1e-20 :  4.138901486368794e-05 :  None : False : False :  Reals
#       (0.0, 'Cl') : 1e-20 :      9.372486258799979 :  None : False : False :  Reals
#       (0.0, 'Dy') : 1e-20 :  4.742057773482856e-05 :  None : False : False :  Reals
#       (0.0, 'Fe') : 1e-20 : 1.8524782464492363e-05 :  None : False : False :  Reals
#       (0.0, 'Gd') : 1e-20 :  4.576826396251711e-05 :  None : False : False :  Reals
#        (0.0, 'H') : 1e-20 :        41.380212256497 :  None : False : False :  Reals
#      (0.0, 'H2O') : 1e-20 :              1000000.0 :  None : False : False :  Reals
#     (0.0, 'HSO4') : 1e-20 : 2.6119872099049513e-05 :  None : False : False :  Reals
#       (0.0, 'La') : 1e-20 :  4.108029335125888e-05 :  None : False : False :  Reals
#       (0.0, 'Nd') : 1e-20 :  4.244947252637724e-05 :  None : False : False :  Reals
#       (0.0, 'Pr') : 1e-20 :  4.170875023006113e-05 :  None : False : False :  Reals
#      (0.0, 'SO4') : 1e-20 :  7.597374047141068e-06 :  None : False : False :  Reals
#       (0.0, 'Sc') : 1e-20 :   2.61869517762183e-05 :  None : False : False :  Reals
#       (0.0, 'Sm') : 1e-20 :  4.401145719179361e-05 :  None : False : False :  Reals
#        (0.0, 'Y') : 1e-20 :  2.891218386233368e-05 :  None : False : False :  Reals
# IndexedVar : Size=1, Index=fs._time, ReferenceTo=fs.solex_cleaner_load.mscontactor.aqueous_inlet_state[:].component('flow_vol')
#     Key : Lower : Value               : Upper : Fixed : Stale : Domain
#     0.0 : 1e-08 : 0.09013073173543751 :  None : False : False :  Reals

# %%
scaled_model.fs.solex_rougher_scrub.pprint()
# Out:
# solex_rougher_scrub : Size=1, Index=None, Active=True
#     2 Param Declarations
#         area_cross_stage : Cross sectional area stage
#             Size=1, Index=fs.solex_rougher_scrub.mscontactor.elements, Domain=Any, Default=None, Mutable=True, Units=m**2
#             Key : Value
#               1 :     1
#         elevation : Elevation of each stage
#             Size=1, Index=fs.solex_rougher_scrub.mscontactor.elements, Domain=Any, Default=None, Mutable=True, Units=m
#             Key : Value
#               1 :     0
#
#     3 Constraint Declarations
#         aqueous_pressure_constraint : Size=1, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  : Upper : Active
#             (0.0, 1) :   0.0 : 99999.99999999999*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].pressure - (0.0009999999999999998*(l*Pa*s**2/m**2/mg)*((fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[H2O] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[H] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[HSO4] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[SO4] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Cl] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Sc] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Y] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[La] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Ce] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Pr] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Nd] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Sm] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Gd] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Dy] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Al] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Ca] + fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[Fe])*(9.80665*m/s**2)*(fs.solex_rougher_scrub.mscontactor.volume[1]*fs.solex_rougher_scrub.mscontactor.volume_frac_stream[0.0,1,aqueous]/fs.solex_rougher_scrub.area_cross_stage[1] + fs.solex_rougher_scrub.elevation[1])) + 0.0009999999999999998*(l*Pa*s**2/m**2/mg)*((fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Kerosene] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[DEHPA] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Al_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Ca_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Fe_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Sc_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Y_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[La_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Ce_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Pr_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Nd_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Sm_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Gd_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Dy_o])*(9.80665*m/s**2)*fs.solex_rougher_scrub.mscontactor.volume[1]*fs.solex_rougher_scrub.mscontactor.volume_frac_stream[0.0,1,organic]/fs.solex_rougher_scrub.area_cross_stage[1]) + 101325*Pa) :   0.0 :   True
#         distribution_extent_constraint : Size=12, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*{('Al', 'Al_o'), ('Ca', 'Ca_o'), ('Fe', 'Fe_o'), ('Sc', 'Sc_o'), ('Y', 'Y_o'), ('Gd', 'Gd_o'), ('Dy', 'Dy_o'), ('Sm', 'Sm_o'), ('La', 'La_o'), ('Pr', 'Pr_o'), ('Ce', 'Ce_o'), ('Nd', 'Nd_o')}, Active=True
#             Key                    : Lower : Body                                                                                                                                                                                                                                       : Upper : Active
#             (0.0, 1, 'Al', 'Al_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Al_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Al]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Al] :   0.0 :   True
#             (0.0, 1, 'Ca', 'Ca_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Ca_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Ca]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Ca] :   0.0 :   True
#             (0.0, 1, 'Ce', 'Ce_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Ce_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Ce]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Ce] :   0.0 :   True
#             (0.0, 1, 'Dy', 'Dy_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Dy_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Dy]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Dy] :   0.0 :   True
#             (0.0, 1, 'Fe', 'Fe_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Fe_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Fe]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Fe] :   0.0 :   True
#             (0.0, 1, 'Gd', 'Gd_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Gd_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Gd]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Gd] :   0.0 :   True
#             (0.0, 1, 'La', 'La_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[La_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[La]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[La] :   0.0 :   True
#             (0.0, 1, 'Nd', 'Nd_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Nd_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Nd]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Nd] :   0.0 :   True
#             (0.0, 1, 'Pr', 'Pr_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Pr_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Pr]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Pr] :   0.0 :   True
#             (0.0, 1, 'Sc', 'Sc_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Sc_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Sc]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Sc] :   0.0 :   True
#             (0.0, 1, 'Sm', 'Sm_o') :   0.0 : fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Sm_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Sm]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Sm] :   0.0 :   True
#               (0.0, 1, 'Y', 'Y_o') :   0.0 :    fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Y_o] - fs.solex_rougher_scrub.mscontactor.heterogeneous_reactions[0.0,1].distribution_coefficient[Y]*fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[Y] :   0.0 :   True
#         organic_pressure_constraint : Size=1, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 : Upper : Active
#             (0.0, 1) :   0.0 : 99999.99999999999*fs.solex_rougher_scrub.mscontactor.organic[0.0,1].pressure - (0.0009999999999999998*(l*Pa*s**2/m**2/mg)*((fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Kerosene] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[DEHPA] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Al_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Ca_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Fe_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Sc_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Y_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[La_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Ce_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Pr_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Nd_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Sm_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Gd_o] + fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Dy_o])*(9.8*m/s**2)*fs.solex_rougher_scrub.mscontactor.volume[1]*fs.solex_rougher_scrub.mscontactor.volume_frac_stream[0.0,1,organic]/fs.solex_rougher_scrub.area_cross_stage[1]) + 101325*Pa) :   0.0 :   True
#
#     1 Block Declarations
#         mscontactor : Size=1, Index=None, Active=True
#             3 Set Declarations
#                 stream_component_interactions : Set of interacting components between streams.
#                     Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :    -- :    Any :    0 :      {}
#                 stream_interactions : Set of interacting streams.
#                     Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     2 :    Any :    1 : {('aqueous', 'organic'),}
#                 streams : Set of streams in unit
#                     Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     1 :    Any :    2 : {'aqueous', 'organic'}
#
#             1 RangeSet Declarations
#                 elements : Set of finite elements in cascade (1 to number of elements)
#                     Dimen=1, Size=1, Bounds=(1, 1)
#                     Key  : Finite : Members
#                     None :   True :     [1]
#
#             10 Var Declarations
#                 aqueous_heterogeneous_reactions_generation : Generation due to heterogeneous reactions
#                     Size=17, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.leach_soln._phase_component_set, Units=mol/h
#                     Key                        : Lower : Value                  : Upper : Fixed : Stale : Domain
#                       (0.0, 1, 'liquid', 'Al') :  None :  0.0013961288656211199 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Ca') :  None :  0.0002175184777428469 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Ce') :  None : 1.0589606379261558e-06 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Cl') :  None :                    0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Dy') :  None : 2.8824683871058517e-11 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Fe') :  None :  0.0010534322928264506 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Gd') :  None :  2.340662299291725e-07 :  None : False :  True :  Reals
#                        (0.0, 1, 'liquid', 'H') :  None : -0.0006271307008949785 :  None : False :  True :  Reals
#                      (0.0, 1, 'liquid', 'H2O') :  None :                    0.0 :  None : False :  True :  Reals
#                     (0.0, 1, 'liquid', 'HSO4') :  None :                    0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'La') :  None :  7.300002052589884e-07 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Nd') :  None : 2.5200160051545276e-07 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Pr') :  None : 1.1867931860253092e-09 :  None : False :  True :  Reals
#                      (0.0, 1, 'liquid', 'SO4') :  None :                    0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Sc') :  None :   7.82298648527302e-07 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Sm') :  None : 2.7071252772045576e-09 :  None : False :  True :  Reals
#                        (0.0, 1, 'liquid', 'Y') :  None :  2.305907176531133e-08 :  None : False :  True :  Reals
#                 aqueous_inherent_reaction_extent : Extent of inherent reactions in stream aqueous
#                     Size=1, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.leach_soln.inherent_reaction_idx, Units=mol/h
#                     Key             : Lower : Value                   : Upper : Fixed : Stale : Domain
#                     (0.0, 1, 'Ka2') :  None : -1.6159705026828768e-14 :  None : False :  True :  Reals
#                 aqueous_inherent_reaction_generation : Generation due to inherent reactions in stream aqueous
#                     Size=17, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.leach_soln._phase_component_set, Units=mol/h
#                     Key                        : Lower : Value                   : Upper : Fixed : Stale : Domain
#                       (0.0, 1, 'liquid', 'Al') :  None :                     0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Ca') :  None :                     0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Ce') :  None :                     0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Cl') :  None :                     0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Dy') :  None :                     0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Fe') :  None :                     0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Gd') :  None :                     0.0 :  None : False :  True :  Reals
#                        (0.0, 1, 'liquid', 'H') :  None : -1.6159705026828768e-14 :  None : False :  True :  Reals
#                      (0.0, 1, 'liquid', 'H2O') :  None :                     0.0 :  None : False :  True :  Reals
#                     (0.0, 1, 'liquid', 'HSO4') :  None :  1.6159705026828794e-14 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'La') :  None :                     0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Nd') :  None :                     0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Pr') :  None :                     0.0 :  None : False :  True :  Reals
#                      (0.0, 1, 'liquid', 'SO4') :  None : -1.6159705026828768e-14 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Sc') :  None :                     0.0 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Sm') :  None :                     0.0 :  None : False :  True :  Reals
#                        (0.0, 1, 'liquid', 'Y') :  None :                     0.0 :  None : False :  True :  Reals
#                 aqueous_material_holdup : Material holdup of stream in element
#                     Size=17, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.leach_soln._phase_component_set, Units=mol
#                     Key                        : Lower : Value                  : Upper : Fixed : Stale : Domain
#                       (0.0, 1, 'liquid', 'Al') :  None :      3.102508591010392 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Ca') :  None :     0.4833743954831282 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Ce') :  None :   0.002353246004796916 :  None : False : False :  Reals
#                       (0.0, 1, 'liquid', 'Cl') :  None :     2.0288268975396826 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Dy') :  None :  6.417792997037708e-08 :  None : False : False :  Reals
#                       (0.0, 1, 'liquid', 'Fe') :  None :      2.340960651083544 :  None : False :  True :  Reals
#                       (0.0, 1, 'liquid', 'Gd') :  None :  0.0005201473048063177 :  None : False : False :  Reals
#                        (0.0, 1, 'liquid', 'H') :  None :     0.6130489114484374 :  None : False : False :  Reals
#                      (0.0, 1, 'liquid', 'H2O') :  None :      11111.11111111111 :  None : False :  True :  Reals
#                     (0.0, 1, 'liquid', 'HSO4') :  None : 2.4209600990587887e-10 :  None : False : False :  Reals
#                       (0.0, 1, 'liquid', 'La') :  None :  0.0016222228223365942 :  None : False : False :  Reals
#                       (0.0, 1, 'liquid', 'Nd') :  None :  0.0005600036953569143 :  None : False : False :  Reals
#                       (0.0, 1, 'liquid', 'Pr') :  None :  2.637460128740443e-06 :  None : False : False :  Reals
#                      (0.0, 1, 'liquid', 'SO4') :  None : 1.7242285377250255e-10 :  None : False : False :  Reals
#                       (0.0, 1, 'liquid', 'Sc') :  None :  0.0017384418859741624 :  None : False : False :  Reals
#                       (0.0, 1, 'liquid', 'Sm') :  None :  6.015966963479613e-06 :  None : False : False :  Reals
#                        (0.0, 1, 'liquid', 'Y') :  None :  5.124260665967384e-05 :  None : False : False :  Reals
#                 heterogeneous_reaction_extent : Extent of heterogeneous reactions
#                     Size=12, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.reaxn.reaction_idx, Units=mol/h
#                     Key                          : Lower : Value                   : Upper : Fixed : Stale : Domain
#                     (0.0, 1, 'Al_mass_transfer') :  None :   -0.001396128865621113 :  None : False :  True :  Reals
#                     (0.0, 1, 'Ca_mass_transfer') :  None :  -0.0002175184777428469 :  None : False :  True :  Reals
#                     (0.0, 1, 'Ce_mass_transfer') :  None : -1.0589606379261558e-06 :  None : False :  True :  Reals
#                     (0.0, 1, 'Dy_mass_transfer') :  None : -2.8824683871058517e-11 :  None : False :  True :  Reals
#                     (0.0, 1, 'Fe_mass_transfer') :  None :  -0.0010534322928264506 :  None : False :  True :  Reals
#                     (0.0, 1, 'Gd_mass_transfer') :  None :  -2.340662299291454e-07 :  None : False :  True :  Reals
#                     (0.0, 1, 'La_mass_transfer') :  None :  -7.300002052589613e-07 :  None : False :  True :  Reals
#                     (0.0, 1, 'Nd_mass_transfer') :  None : -2.5200160051545276e-07 :  None : False :  True :  Reals
#                     (0.0, 1, 'Pr_mass_transfer') :  None : -1.1867931860253092e-09 :  None : False :  True :  Reals
#                     (0.0, 1, 'Sc_mass_transfer') :  None :   -7.82298648527302e-07 :  None : False :  True :  Reals
#                     (0.0, 1, 'Sm_mass_transfer') :  None : -2.7071252772045576e-09 :  None : False :  True :  Reals
#                      (0.0, 1, 'Y_mass_transfer') :  None :  -2.305907176520291e-08 :  None : False :  True :  Reals
#                 material_transfer_term : Inter-stream mass transfer term
#                     Size=0, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.solex_rougher_scrub.mscontactor.stream_component_interactions, Units=mol/h
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 organic_heterogeneous_reactions_generation : Generation due to heterogeneous reactions
#                     Size=14, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.prop_o._phase_component_set, Units=mol/h
#                     Key                             : Lower : Value                   : Upper : Fixed : Stale : Domain
#                         (0.0, 1, 'organic', 'Al_o') :  None :   -0.001396128865621113 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Ca_o') :  None :  -0.0002175184777428469 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Ce_o') :  None : -1.0589606379261558e-06 :  None : False :  True :  Reals
#                        (0.0, 1, 'organic', 'DEHPA') :  None :    0.007792973358239592 :  None : False : False :  Reals
#                         (0.0, 1, 'organic', 'Dy_o') :  None : -2.8824683871058517e-11 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Fe_o') :  None :  -0.0010534322928264506 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Gd_o') :  None :  -2.340662299291454e-07 :  None : False :  True :  Reals
#                     (0.0, 1, 'organic', 'Kerosene') :  None :                     0.0 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'La_o') :  None :  -7.300002052589613e-07 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Nd_o') :  None : -2.5200160051545276e-07 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Pr_o') :  None : -1.1867931860253092e-09 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Sc_o') :  None :   -7.82298648527302e-07 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Sm_o') :  None : -2.7071252772045576e-09 :  None : False :  True :  Reals
#                          (0.0, 1, 'organic', 'Y_o') :  None :  -2.305907176520291e-08 :  None : False :  True :  Reals
#                 organic_material_holdup : Material holdup of stream in element
#                     Size=14, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.prop_o._phase_component_set, Units=mol
#                     Key                             : Lower : Value                  : Upper : Fixed : Stale : Domain
#                         (0.0, 1, 'organic', 'Al_o') :  None :     0.1647432061826517 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Ca_o') :  None :    0.03180603522278991 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Ce_o') :  None :  0.0005515040118257986 :  None : False : False :  Reals
#                        (0.0, 1, 'organic', 'DEHPA') :  None :      603.6955848811158 :  None : False : False :  Reals
#                         (0.0, 1, 'organic', 'Dy_o') :  None : 0.00010319951391779547 :  None : False : False :  Reals
#                         (0.0, 1, 'organic', 'Fe_o') :  None :    0.35020771340210355 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'Gd_o') :  None : 0.00040646306138614197 :  None : False : False :  Reals
#                     (0.0, 1, 'organic', 'Kerosene') :  None :      964.7058823529411 :  None : False :  True :  Reals
#                         (0.0, 1, 'organic', 'La_o') :  None : 0.00045710888938044203 :  None : False : False :  Reals
#                         (0.0, 1, 'organic', 'Nd_o') :  None : 0.00027857808577069765 :  None : False : False :  Reals
#                         (0.0, 1, 'organic', 'Pr_o') :  None : 2.7678007387121895e-05 :  None : False : False :  Reals
#                         (0.0, 1, 'organic', 'Sc_o') :  None :      1.099560320629984 :  None : False : False :  Reals
#                         (0.0, 1, 'organic', 'Sm_o') :  None :  8.786808600902418e-05 :  None : False : False :  Reals
#                          (0.0, 1, 'organic', 'Y_o') :  None :  0.0018863591632904964 :  None : False : False :  Reals
#                 volume : Volume of element
#                     Size=1, Index=fs.solex_rougher_scrub.mscontactor.elements, Units=m**3
#                     Key : Lower : Value : Upper : Fixed : Stale : Domain
#                       1 :  None :   0.4 :  None :  True : False :  Reals
#                 volume_frac_stream : Volume fraction of each stream in element
#                     Size=2, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.solex_rougher_scrub.mscontactor.streams, Units=dimensionless
#                     Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#                     (0.0, 1, 'aqueous') :  None :   0.5 :  None :  True : False :  Reals
#                     (0.0, 1, 'organic') :  None :   0.5 :  None : False :  True :  Reals
#
#             2 Expression Declarations
#                 aqueous_phase_fraction : Volume fraction of holdup by phase in stream aqueous
#                     Size=1, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.leach_soln.phase_list
#                     Key                : Expression
#                     (0.0, 1, 'liquid') :        1.0
#                 organic_phase_fraction : Volume fraction of holdup by phase in stream organic
#                     Size=1, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.prop_o.phase_list
#                     Key                 : Expression
#                     (0.0, 1, 'organic') :        1.0
#
#             8 Constraint Declarations
#                 aqueous_heterogeneous_reaction_constraint : Heterogeneous reaction stoichiometry constraint
#                     Size=17, Index=fs._time*fs.solex_rougher_scrub.mscontactor.elements*fs.leach_soln._phase_component_set, Active=True
#                     Key                        : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       : Upper : Active
#                       (0.0, 1, 'liquid', 'Al') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,Al] + fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Al_mass_transfer] :   0.0 :   True
#                       (0.0, 1, 'liquid', 'Ca') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,Ca] + fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Ca_mass_transfer] :   0.0 :   True
#                       (0.0, 1, 'liquid', 'Ce') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,Ce] + fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Ce_mass_transfer] :   0.0 :   True
#                       (0.0, 1, 'liquid', 'Cl') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,Cl] :   0.0 :   True
#                       (0.0, 1, 'liquid', 'Dy') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,Dy] + fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Dy_mass_transfer] :   0.0 :   True
#                       (0.0, 1, 'liquid', 'Fe') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,Fe] + fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Fe_mass_transfer] :   0.0 :   True
#                       (0.0, 1, 'liquid', 'Gd') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,Gd] + fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Gd_mass_transfer] :   0.0 :   True
#                        (0.0, 1, 'liquid', 'H') :   0.0 : fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,H] - (3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,La_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Y_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Pr_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Ce_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Nd_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Sm_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Gd_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Dy_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Al_mass_transfer] + 2*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Ca_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Fe_mass_transfer] + 3*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Sc_mass_transfer]) :   0.0 :   True
#                      (0.0, 1, 'liquid', 'H2O') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,H2O] :   0.0 :   True
#                     (0.0, 1, 'liquid', 'HSO4') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,HSO4] - (0*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,La_mass_transfer] + 0*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Y_mass_transfer] + 0*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Pr_mass_transfer] + 0*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Ce_mass_transfer] + 0*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Nd_mass_transfer] + 0*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Sm_mass_transfer] + 0*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Gd_mass_transfer] + 0*fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Dy_mass_transfer]) :   0.0 :   True
#                       (0.0, 1, 'liquid', 'La') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,La] + fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,La_mass_transfer] :   0.0 :   True
#                       (0.0, 1, 'liquid', 'Nd') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,Nd] + fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Nd_mass_transfer] :   0.0 :   True
#                       (0.0, 1, 'liquid', 'Pr') :   0.0 :                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  fs.solex_rougher_scrub.mscontactor.aqueous_heterogeneous_reactions_generation[0.0,1,liquid,Pr] + fs.solex_rougher_scrub.mscontactor.heterogeneous_reaction_extent[0.0,1,Pr_mass_transfer] :   0.0 :   True
# ...
#                                 Kerosene :   0.0 : 1000000.0000000001*(mg/kg)*fs.prop_o.mw[Kerosene]*fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Kerosene] - fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Kerosene] :   0.0 :   True
#                                     La_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[La_o]*fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[La_o] - fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[La_o] :   0.0 :   True
#                                     Nd_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Nd_o]*fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Nd_o] - fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Nd_o] :   0.0 :   True
#                                     Pr_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Pr_o]*fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Pr_o] - fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Pr_o] :   0.0 :   True
#                                     Sc_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Sc_o]*fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Sc_o] - fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Sc_o] :   0.0 :   True
#                                     Sm_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Sm_o]*fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Sm_o] - fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Sm_o] :   0.0 :   True
#                                      Y_o :   0.0 :                1000000.0000000001*(mg/kg)*fs.prop_o.mw[Y_o]*fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mol_comp[Y_o] - fs.solex_rougher_scrub.mscontactor.organic[0.0,1].conc_mass_comp[Y_o] :   0.0 :   True
#
#                         1 Suffix Declarations
#                             scaling_factor : Direction=EXPORT, Datatype=FLOAT
#                                 Key                                                           : Value
#                                    fs.solex_rougher_scrub.mscontactor.organic[0.0,1].pressure : 1e-05
#                                 fs.solex_rougher_scrub.mscontactor.organic[0.0,1].temperature :  0.01
#
#                         8 Declarations: conc_mass_comp flow_vol conc_mol_comp temperature pressure molar_concentration_constraint kerosene_concentration scaling_factor
#                 organic_inlet_state : Inlet states for stream organic.
#                     Size=1, Index=fs._time, Active=True
#                     fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0] : Active=True
#                         5 Var Declarations
#                             conc_mass_comp : Size=14, Index=fs.prop_o.component_list, Units=mg/l
#                                 Key      : Lower : Value               : Upper : Fixed : Stale : Domain
#                                     Al_o : 1e-20 :  22.832994239154104 :  None :  True : False :  Reals
#                                     Ca_o : 1e-20 :   6.514196877265651 :  None :  True : False :  Reals
#                                     Ce_o : 1e-20 :  0.3887654773916162 :  None :  True : False :  Reals
#                                    DEHPA : 1e-20 :   973210.3348217038 :  None :  True : False :  Reals
#                                     Dy_o : 1e-20 : 0.08384968059454774 :  None :  True : False :  Reals
#                                     Fe_o : 1e-20 :   98.73544940996915 :  None :  True : False :  Reals
#                                     Gd_o : 1e-20 :   0.320175146192493 :  None :  True : False :  Reals
#                                 Kerosene : 1e-20 :            820000.0 :  None :  True : False :  Reals
#                                     La_o : 1e-20 : 0.31910878246470614 :  None :  True : False :  Reals
#                                     Nd_o : 1e-20 : 0.20149948435205733 :  None :  True : False :  Reals
#                                     Pr_o : 1e-20 : 0.01950282171672067 :  None :  True : False :  Reals
#                                     Sc_o : 1e-20 :  247.10475787977003 :  None :  True : False :  Reals
#                                     Sm_o : 1e-20 : 0.06606579121831983 :  None :  True : False :  Reals
#                                      Y_o : 1e-20 :  0.8385668673225714 :  None :  True : False :  Reals
#                             conc_mol_comp : Size=14, Index=fs.prop_o.component_list, Units=mol/l
#                                 Key      : Lower : Value                  : Upper : Fixed : Stale : Domain
#                                     Al_o : 1e-20 :  0.0008462306070400306 :  None : False :  True :  Reals
#                                     Ca_o : 1e-20 : 0.00016253797288451644 :  None : False :  True :  Reals
#                                     Ce_o : 1e-20 : 2.7745973150219553e-06 :  None : False :  True :  Reals
#                                    DEHPA : 1e-20 :     3.0183522515567787 :  None : False :  True :  Reals
#                                     Dy_o : 1e-20 :  5.159980344279856e-07 :  None : False :  True :  Reals
#                                     Fe_o : 1e-20 :  0.0017680266704265225 :  None : False :  True :  Reals
#                                     Gd_o : 1e-20 : 2.0360899598886667e-06 :  None : False :  True :  Reals
#                                 Kerosene : 1e-20 :      4.823529411764706 :  None : False :  True :  Reals
#                                     La_o : 1e-20 :  2.297316745003462e-06 :  None : False :  True :  Reals
#                                     Nd_o : 1e-20 : 1.3969543153315775e-06 :  None : False :  True :  Reals
#                                     Pr_o : 1e-20 :  1.384091756741721e-07 :  None : False :  True :  Reals
#                                     Sc_o : 1e-20 :   0.005497814218835269 :  None : False :  True :  Reals
#                                     Sm_o : 1e-20 :   4.39384086314976e-07 :  None : False :  True :  Reals
#                                      Y_o : 1e-20 :  9.432167676987472e-06 :  None : False :  True :  Reals
#                             flow_vol : Size=1, Index=None, Units=l/h
#                                 Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                                 None : 1e-08 : 62.01 :  None :  True : False :  Reals
#                             pressure : State pressure [Pa]
#                                 Size=1, Index=None, Units=Pa
#                                 Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#                                 None :  0.01 : 1.101135800227954 :  10.0 :  True : False :  Reals
#                             temperature : State temperature [K]
#                                 Size=1, Index=None, Units=K
#                                 Key  : Lower  : Value : Upper : Fixed : Stale : Domain
#                                 None : 2.9815 :  3.03 :  None :  True : False :  Reals
#
#                         1 Constraint Declarations
#                             molar_concentration_constraint : Size=14, Index=fs.prop_o.component_list, Active=True
#                                 Key      : Lower : Body                                                                                                                                                                                                                         : Upper : Active
#                                     Al_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Al_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Al_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Al_o] :   0.0 :   True
#                                     Ca_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Ca_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Ca_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Ca_o] :   0.0 :   True
#                                     Ce_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Ce_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Ce_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Ce_o] :   0.0 :   True
#                                    DEHPA :   0.0 :          1000000.0000000001*(mg/kg)*fs.prop_o.mw[DEHPA]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[DEHPA] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[DEHPA] :   0.0 :   True
#                                     Dy_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Dy_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Dy_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Dy_o] :   0.0 :   True
#                                     Fe_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Fe_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Fe_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Fe_o] :   0.0 :   True
#                                     Gd_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Gd_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Gd_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Gd_o] :   0.0 :   True
#                                 Kerosene :   0.0 : 1000000.0000000001*(mg/kg)*fs.prop_o.mw[Kerosene]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Kerosene] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Kerosene] :   0.0 :   True
#                                     La_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[La_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[La_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[La_o] :   0.0 :   True
#                                     Nd_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Nd_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Nd_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Nd_o] :   0.0 :   True
#                                     Pr_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Pr_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Pr_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Pr_o] :   0.0 :   True
#                                     Sc_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Sc_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Sc_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Sc_o] :   0.0 :   True
#                                     Sm_o :   0.0 :             1000000.0000000001*(mg/kg)*fs.prop_o.mw[Sm_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Sm_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Sm_o] :   0.0 :   True
#                                      Y_o :   0.0 :                1000000.0000000001*(mg/kg)*fs.prop_o.mw[Y_o]*fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mol_comp[Y_o] - fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].conc_mass_comp[Y_o] :   0.0 :   True
#
#                         1 Suffix Declarations
#                             scaling_factor : Direction=EXPORT, Datatype=FLOAT
#                                 Key                                                                     : Value
#                                    fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].pressure : 1e-05
#                                 fs.solex_rougher_scrub.mscontactor.organic_inlet_state[0.0].temperature :  0.01
#
#                         7 Declarations: conc_mass_comp flow_vol conc_mol_comp temperature pressure molar_concentration_constraint scaling_factor
#
#             4 Port Declarations
#                 aqueous_inlet : aqueous Inlet
#                     Size=1, Index=None
#                     Key  : Name           : Size : Variable
#                     None : conc_mass_comp :   17 : IndexedVar
#                          :       flow_vol :    1 : IndexedVar
#                          :       pressure :    1 : IndexedVar
#                          :    temperature :    1 : IndexedVar
#                 aqueous_outlet : aqueous Outlet
#                     Size=1, Index=None
#                     Key  : Name           : Size : Variable
#                     None : conc_mass_comp :   17 : IndexedVar
#                          :       flow_vol :    1 : IndexedVar
#                          :       pressure :    1 : IndexedVar
#                          :    temperature :    1 : IndexedVar
#                 organic_inlet : organic Inlet
#                     Size=1, Index=None
#                     Key  : Name           : Size : Variable
#                     None : conc_mass_comp :   14 : IndexedVar
#                          :       flow_vol :    1 : IndexedVar
#                          :       pressure :    1 : IndexedVar
#                          :    temperature :    1 : IndexedVar
#                 organic_outlet : organic Outlet
#                     Size=1, Index=None
#                     Key  : Name           : Size : Variable
#                     None : conc_mass_comp :   14 : IndexedVar
#                          :       flow_vol :    1 : IndexedVar
#                          :       pressure :    1 : IndexedVar
#                          :    temperature :    1 : IndexedVar
#
#             33 Declarations: elements streams stream_interactions stream_component_interactions aqueous aqueous_inlet_state organic organic_inlet_state heterogeneous_reactions volume volume_frac_stream sum_volume_frac aqueous_phase_fraction organic_phase_fraction material_transfer_term heterogeneous_reaction_extent aqueous_material_holdup aqueous_material_holdup_constraint aqueous_inherent_reaction_extent aqueous_inherent_reaction_generation aqueous_inherent_reaction_constraint aqueous_heterogeneous_reactions_generation aqueous_heterogeneous_reaction_constraint aqueous_material_balance organic_material_holdup organic_material_holdup_constraint organic_heterogeneous_reactions_generation organic_heterogeneous_reaction_constraint organic_material_balance aqueous_inlet aqueous_outlet organic_inlet organic_outlet
#
#     4 Port Declarations
#         aqueous_inlet : Size=1, Index=None
#             Key  : Name           : Size : Variable
#             None : conc_mass_comp :   17 : IndexedVar
#                  :       flow_vol :    1 : IndexedVar
#                  :       pressure :    1 : IndexedVar
#                  :    temperature :    1 : IndexedVar
#         aqueous_outlet : Size=1, Index=None
#             Key  : Name           : Size : Variable
#             None : conc_mass_comp :   17 : IndexedVar
#                  :       flow_vol :    1 : IndexedVar
#                  :       pressure :    1 : IndexedVar
#                  :    temperature :    1 : IndexedVar
#         organic_inlet : Size=1, Index=None
#             Key  : Name           : Size : Variable
#             None : conc_mass_comp :   14 : IndexedVar
#                  :       flow_vol :    1 : IndexedVar
#                  :       pressure :    1 : IndexedVar
#                  :    temperature :    1 : IndexedVar
#         organic_outlet : Size=1, Index=None
#             Key  : Name           : Size : Variable
#             None : conc_mass_comp :   14 : IndexedVar
#                  :       flow_vol :    1 : IndexedVar
#                  :       pressure :    1 : IndexedVar
#                  :    temperature :    1 : IndexedVar
#
#     10 Declarations: mscontactor distribution_extent_constraint area_cross_stage elevation aqueous_pressure_constraint organic_pressure_constraint aqueous_inlet aqueous_outlet organic_inlet organic_outlet
